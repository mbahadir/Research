# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\bahad\\GitHub\\Research\\Models'

# %%
pd.set_option("display.max_columns", None)

# %% [markdown]
# # Data Loading

# %%
data_initial=pd.read_csv("D:/Datasets/m5-forecasting-accuracy/Obtained_Data/second_scenario_group.csv",dtype={"event_name_1": object,
                                                                                         "event_type_1": object,
                                                                                         "event_name_2": object,
                                                                                         "event_type_2": object,},index_col=0)

# %%
data_initial["date"]=pd.to_datetime(data_initial["date"])

# %%
data_initial.event_name_1.value_counts()
# Out:
# SuperBowl              18
# StPatricksDay          18
# PresidentsDay          18
# Purim End              18
# LentWeek2              18
# LentStart              18
# ValentinesDay          18
# NBAFinalsStart         15
# EidAlAdha              15
# IndependenceDay        15
# Pesach End             15
# VeteransDay            15
# Ramadan starts         15
# Chanukah End           15
# NBAFinalsEnd           15
# LaborDay               15
# MemorialDay            15
# Eid al-Fitr            15
# Halloween              15
# Mother's day           15
# OrthodoxChristmas      15
# Christmas              15
# Thanksgiving           15
# ColumbusDay            15
# NewYear                15
# Easter                 15
# MartinLutherKingDay    15
# Cinco De Mayo          12
# OrthodoxEaster         12
# Father's day           12
# Name: event_name_1, dtype: int64

# %%
data_initial.head()
# Out:
#   store_id       date  Total_sales  Sales event_name_1 event_type_1  \
# 0     TX_1 2011-01-29         1124     58          NaN          NaN
# 1     TX_1 2011-01-30         1124     62          NaN          NaN
# 2     TX_1 2011-01-31         1124     41          NaN          NaN
# 3     TX_1 2011-02-01         1124     46          NaN          NaN
# 4     TX_1 2011-02-02         1124     28          NaN          NaN
#
#   event_name_2 event_type_2  snap_CA  snap_TX  snap_WI  sell_price_mean  \
# 0          NaN          NaN        0        0        0       5.95971429
# 1          NaN          NaN        0        0        0       5.95971429
# 2          NaN          NaN        0        0        0       5.95971429
# 3          NaN          NaN        1        1        0       5.95971429
# 4          NaN          NaN        1        0        1       5.95971429
#
#    sell_price_median  sell_price_std         CA         TX         WI  \
# 0         5.05000000      4.09462637 0.00000000 1.00000000 0.00000000
# 1         5.05000000      4.09462637 0.00000000 1.00000000 0.00000000
# 2         5.05000000      4.09462637 0.00000000 1.00000000 0.00000000
# 3         5.05000000      4.09462637 0.00000000 1.00000000 0.00000000
# 4         5.05000000      4.09462637 0.00000000 1.00000000 0.00000000
#
#       Friday     Monday   Saturday     Sunday   Thursday    Tuesday  \
# 0 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000
# 1 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000
# 2 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 3 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000
# 4 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
#
#    Wednesday        Jan        Feb        Mar        Apr        May  \
# 0 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 2 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 3 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000
# 4 1.00000000 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000
#
#         June       July        Agu        Sep        Oct        Nov  \
# 0 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 2 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 3 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 4 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
#
#          Dec      _2011      _2012      _2013      _2014      _2015      _2016
# 0 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 2 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 3 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 4 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000

# %% [markdown]
# ## Event Conversion

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
hot_encoder=OneHotEncoder()

# %% [markdown]
# ## Event

# %%
data_initial.drop(["event_name_1", "event_name_2", "event_type_2", "CA", "TX", "WI"], axis=1, inplace=True)

# %%
data_initial[data_initial["event_type_1"].isna()]["event_type_1"]=0
data_initial["event_type_1"]=data_initial["event_type_1"].astype(str)
# Out:
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
encoded_event=hot_encoder.fit_transform(data_initial[["event_type_1"]])
array_event=encoded_event.toarray()

# %%
hot_encoder.categories_
# Out:
# [array(['Cultural', 'National', 'Religious', 'Sporting', 'nan'],
#        dtype=object)]

# %%
event_df=pd.DataFrame(array_event,columns=["Cultural", "National", "Religious", "Sporting", 'nan'])

# %% [markdown]
# ## Store Id

# %%
encoded_store=hot_encoder.fit_transform(data_initial[["store_id"]])
array_store=encoded_store.toarray()

# %%
hot_encoder.categories_
# Out:
# [array(['TX_1', 'TX_2', 'TX_3'], dtype=object)]

# %%
store_df=pd.DataFrame(array_store, columns=['TX_1', 'TX_2', 'TX_3'])

# %%
frames=[data_initial, event_df, store_df]
data=pd.concat(frames, axis=1)

# %%
data.drop(["event_type_1", "nan", "Total_sales", "store_id"], axis=1, inplace=True)

# %%
data.head()
# Out:
#         date  Sales  snap_CA  snap_TX  snap_WI  sell_price_mean  \
# 0 2011-01-29     58        0        0        0       5.95971429
# 1 2011-01-30     62        0        0        0       5.95971429
# 2 2011-01-31     41        0        0        0       5.95971429
# 3 2011-02-01     46        1        1        0       5.95971429
# 4 2011-02-02     28        1        0        1       5.95971429
#
#    sell_price_median  sell_price_std     Friday     Monday   Saturday  \
# 0         5.05000000      4.09462637 0.00000000 0.00000000 1.00000000
# 1         5.05000000      4.09462637 0.00000000 0.00000000 0.00000000
# 2         5.05000000      4.09462637 0.00000000 1.00000000 0.00000000
# 3         5.05000000      4.09462637 0.00000000 0.00000000 0.00000000
# 4         5.05000000      4.09462637 0.00000000 0.00000000 0.00000000
#
#       Sunday   Thursday    Tuesday  Wednesday        Jan        Feb  \
# 0 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000
# 1 1.00000000 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000
# 2 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000
# 3 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000 1.00000000
# 4 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000 1.00000000
#
#          Mar        Apr        May       June       July        Agu  \
# 0 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 2 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 3 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 4 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
#
#          Sep        Oct        Nov        Dec      _2011      _2012  \
# 0 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000
# 1 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000
# 2 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000
# 3 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000
# 4 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000
#
#        _2013      _2014      _2015      _2016   Cultural   National  \
# 0 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 2 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 3 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 4 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
#
#    Religious   Sporting       TX_1       TX_2       TX_3
# 0 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000
# 1 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000
# 2 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000
# 3 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000
# 4 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000

# %%
data.describe()
# Out:
#                Sales        snap_CA        snap_TX        snap_WI  \
# count 5,739.00000000 5,739.00000000 5,739.00000000 5,739.00000000
# mean     60.67868967     0.32932567     0.32932567     0.32932567
# std      18.63061857     0.47000932     0.47000932     0.47000932
# min       0.00000000     0.00000000     0.00000000     0.00000000
# 25%      47.00000000     0.00000000     0.00000000     0.00000000
# 50%      59.00000000     0.00000000     0.00000000     0.00000000
# 75%      72.00000000     1.00000000     1.00000000     1.00000000
# max     183.00000000     1.00000000     1.00000000     1.00000000
#
#        sell_price_mean  sell_price_median  sell_price_std         Friday  \
# count   5,739.00000000     5,739.00000000  5,739.00000000 5,739.00000000
# mean        6.36491333         5.28427775      4.71342827     0.14270779
# std         0.43113875         0.29836544      0.66243042     0.34980508
# min         5.44641509         4.48000000      3.42894062     0.00000000
# 25%         6.03906250         4.97000000      4.09594295     0.00000000
# 50%         6.39890756         5.36000000      4.51442489     0.00000000
# 75%         6.79873134         5.48000000      5.21934459     0.00000000
# max         7.04031496         5.82500000      5.80084740     1.00000000
#
#               Monday       Saturday         Sunday       Thursday  \
# count 5,739.00000000 5,739.00000000 5,739.00000000 5,739.00000000
# mean      0.14270779     0.14323053     0.14323053     0.14270779
# std       0.34980508     0.35033831     0.35033831     0.34980508
# min       0.00000000     0.00000000     0.00000000     0.00000000
# 25%       0.00000000     0.00000000     0.00000000     0.00000000
# 50%       0.00000000     0.00000000     0.00000000     0.00000000
# 75%       0.00000000     0.00000000     0.00000000     0.00000000
# max       1.00000000     1.00000000     1.00000000     1.00000000
#
#              Tuesday      Wednesday            Jan            Feb  \
# count 5,739.00000000 5,739.00000000 5,739.00000000 5,739.00000000
# mean      0.14270779     0.14270779     0.08259279     0.08886566
# std       0.34980508     0.34980508     0.27528971     0.28457453
# min       0.00000000     0.00000000     0.00000000     0.00000000
# 25%       0.00000000     0.00000000     0.00000000     0.00000000
# 50%       0.00000000     0.00000000     0.00000000     0.00000000
# 75%       0.00000000     0.00000000     0.00000000     0.00000000
# max       1.00000000     1.00000000     1.00000000     1.00000000
#
#                  Mar            Apr            May           June  \
# count 5,739.00000000 5,739.00000000 5,739.00000000 5,739.00000000
# mean      0.09722948     0.09095661     0.08102457     0.07841087
# std       0.29629581     0.28757246     0.27289662     0.26884048
# min       0.00000000     0.00000000     0.00000000     0.00000000
# 25%       0.00000000     0.00000000     0.00000000     0.00000000
# 50%       0.00000000     0.00000000     0.00000000     0.00000000
# 75%       0.00000000     0.00000000     0.00000000     0.00000000
# max       1.00000000     1.00000000     1.00000000     1.00000000
#
#                 July            Agu            Sep            Oct  \
# count 5,739.00000000 5,739.00000000 5,739.00000000 5,739.00000000
# mean      0.08102457     0.08102457     0.07841087     0.08102457
# std       0.27289662     0.27289662     0.26884048     0.27289662
# min       0.00000000     0.00000000     0.00000000     0.00000000
# 25%       0.00000000     0.00000000     0.00000000     0.00000000
# 50%       0.00000000     0.00000000     0.00000000     0.00000000
# 75%       0.00000000     0.00000000     0.00000000     0.00000000
# max       1.00000000     1.00000000     1.00000000     1.00000000
#
#                  Nov            Dec          _2011          _2012  \
# count 5,739.00000000 5,739.00000000 5,739.00000000 5,739.00000000
# mean      0.07841087     0.08102457     0.17616309     0.19132253
# std       0.26884048     0.27289662     0.38099206     0.39337664
# min       0.00000000     0.00000000     0.00000000     0.00000000
# 25%       0.00000000     0.00000000     0.00000000     0.00000000
# 50%       0.00000000     0.00000000     0.00000000     0.00000000
# 75%       0.00000000     0.00000000     0.00000000     0.00000000
# max       1.00000000     1.00000000     1.00000000     1.00000000
#
#                _2013          _2014          _2015          _2016  \
# count 5,739.00000000 5,739.00000000 5,739.00000000 5,739.00000000
# mean      0.19079979     0.19079979     0.19079979     0.06011500
# std       0.39296582     0.39296582     0.39296582     0.23772050
# min       0.00000000     0.00000000     0.00000000     0.00000000
# 25%       0.00000000     0.00000000     0.00000000     0.00000000
# 50%       0.00000000     0.00000000     0.00000000     0.00000000
# 75%       0.00000000     0.00000000     0.00000000     0.00000000
# max       1.00000000     1.00000000     1.00000000     1.00000000
#
#             Cultural       National      Religious       Sporting  \
# count 5,739.00000000 5,739.00000000 5,739.00000000 5,739.00000000
# mean      0.01829587     0.02665970     0.02718244     0.00836383
# std       0.13403082     0.16110084     0.16262890     0.09107864
# min       0.00000000     0.00000000     0.00000000     0.00000000
# 25%       0.00000000     0.00000000     0.00000000     0.00000000
# 50%       0.00000000     0.00000000     0.00000000     0.00000000
# 75%       0.00000000     0.00000000     0.00000000     0.00000000
# max       1.00000000     1.00000000     1.00000000     1.00000000
#
#                 TX_1           TX_2           TX_3
# count 5,739.00000000 5,739.00000000 5,739.00000000
# mean      0.33333333     0.33333333     0.33333333
# std       0.47144560     0.47144560     0.47144560
# min       0.00000000     0.00000000     0.00000000
# 25%       0.00000000     0.00000000     0.00000000
# 50%       0.00000000     0.00000000     0.00000000
# 75%       1.00000000     1.00000000     1.00000000
# max       1.00000000     1.00000000     1.00000000

# %% [markdown]
# # Performance Function

# %%
def performance_list(ID, forecast, actual):
    name=ID
    n=len(actual)
    error=actual-forecast
    mean=np.mean(actual)
    sd=actual.std()
    FBias=sum(error)/sum(actual)
    MPE=sum(error/actual)/n
    MAPE=sum(abs(error/actual))/n
    RMSE=np.sqrt(sum(error**2))/n
    MAD=sum(abs(error))/n
    WMAPE=MAD/mean
    result_df=pd.DataFrame({"Name" :       name ,
                            "# of inst":       n,
                            "Mean":         mean,
                            "Standard Dev.":  sd, 
                            "FBias":       FBias, 
                            "MPE":           MPE, 
                            "MAPE":         MAPE,                                      
                            "RMSE":         RMSE, 
                            "MAD":           MAD, 
                            "WMAPE":      WMAPE}, index=[0])
    return(result_df)

# %%
plt.plot(data[data["TX_1"]==1].Sales)

# %%
# data['trend']=(data["date"]-data["date"].min()).dt.days

# %%
data.fillna(method="ffill", inplace=True)

# %% [markdown]
# ### Train & Test

# %%
# train=data[data["date"]<((data["date"].max()-data["date"].min())*0.8)+data["date"].min()]

# %%
# test=data[data["date"]>=((data["date"].max()-data["date"].min())*0.8)+data["date"].min()]
# test.reset_index(drop=True, inplace=True)

# %% [markdown]
# ### Train & Test Actual

# %%
import datetime as datetime

# %%
test_lenght=28
specific_date=data["date"].max()-datetime.timedelta(28)

# %%
train=data[data["date"]<=specific_date]

# %%
test=data[data["date"]>specific_date]
test.reset_index(drop=True, inplace=True)

# %% [markdown]
# ### Date and Customer Drop

# %%
train=train.drop(["date"], axis=1)
test=test.drop(["date"], axis=1)

# %%
X_train, y_train=train.drop(["Sales"], axis=1), train["Sales"]
X_test, y_test=test.drop(["Sales"], axis=1), test["Sales"]

# %% [markdown]
# # Linear Regression-Elastic Net

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.linear_model import ElasticNet

# %% [markdown]
# ### Grid

# %%
elastic_net_model = ElasticNet()

# %%
param_grid_elastic=[
    {"alpha":[0.1,0.2,0.3,0.4], "l1_ratio":[0.2,0.4,0.6]}
]

# %%
elastic_net = GridSearchCV(estimator=elastic_net_model, param_grid=param_grid_elastic,
                 cv=10,return_train_score=True)

# %%
elastic_net.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=10, estimator=ElasticNet(),
#              param_grid=[{'alpha': [0.1, 0.2, 0.3, 0.4],
#                           'l1_ratio': [0.2, 0.4, 0.6]}],
#              return_train_score=True)

# %%
elastic_predictions=elastic_net.predict(X_test)

# %%
performance_list("Control", elastic_net.predict(X_train), y_train)
# Out:
#       Name  # of inst        Mean  Standard Dev.       FBias  MPE  MAPE  \
# 0  Control       5655 60.40954907    18.49760013 -0.00000000 -inf   inf
#
#         RMSE         MAD      WMAPE
# 0 0.18283123 10.54149266 0.17450044

# %%
res_elastic=performance_list("Elastic Net Performance", elastic_predictions, y_test)

# %%
res_elastic
# Out:
#                       Name  # of inst        Mean  Standard Dev.      FBias  \
# 0  Elastic Net Performance         84 78.79761905    18.72230791 0.08416746
#
#          MPE       MAPE       RMSE         MAD      WMAPE
# 0 0.04703632 0.15450885 1.78080546 12.61592555 0.16010542

# %% [markdown]
# # Support Vector Machines

# %% [markdown]
# ### Linear

# %%
from sklearn.svm import LinearSVR

# %%
sv_regressor=LinearSVR()

# %% [markdown]
# ### Grid

# %%
param_grid_svm_linear=[
    {"epsilon":[0.5,1,1.5]}
]

# %%
sv_regressor = GridSearchCV(estimator=sv_regressor, param_grid=param_grid_svm_linear,
                 cv=10,return_train_score=True)

# %%
sv_regressor.fit(X_train, y_train)
# Out:
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# GridSearchCV(cv=10, estimator=LinearSVR(),
#              param_grid=[{'epsilon': [0.5, 1, 1.5]}], return_train_score=True)

# %% [markdown]
# ### Poly with Kernel

# %%
from sklearn.svm import SVR

# %% [markdown]
# ### Grid

# %%
param_grid_svm_poly=[
    {"degree":[2,3], "epsilon":[0.02,0.05, 0.1, 0.15, 0.2]}
]

# %%
sv_regressor_poly=SVR(kernel="poly")

# %%
sv_regressor_poly = GridSearchCV(estimator=sv_regressor_poly, param_grid=param_grid_svm_poly,
                 cv=10,return_train_score=True)

# %%
sv_regressor_poly.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=10, estimator=SVR(kernel='poly'),
#              param_grid=[{'degree': [2, 3],
#                           'epsilon': [0.02, 0.05, 0.1, 0.15, 0.2]}],
#              return_train_score=True)

# %%
sv_regressor_poly.best_estimator_
# Out:
# SVR(degree=2, epsilon=0.2, kernel='poly')

# %% [markdown]
# ### Predictions

# %%
svm_predictions_linear=sv_regressor.predict(X_test)

# %%
res_svr_linear=performance_list("Support Vector Regressor Linear Performance", svm_predictions_linear, y_test)

# %%
svm_predictions_poly=sv_regressor_poly.predict(X_test)

# %%
res_svr_poly=performance_list("Support Vector Regressor Polynomial Performance", svm_predictions_poly, y_test)

# %%
performance_list("Control", sv_regressor.predict(X_train), y_train)
# Out:
#       Name  # of inst        Mean  Standard Dev.      FBias  MPE  MAPE  \
# 0  Control       5655 60.40954907    18.49760013 0.00907848 -inf   inf
#
#         RMSE         MAD      WMAPE
# 0 0.18522173 10.57386294 0.17503628

# %%
performance_list("Control", sv_regressor_poly.predict(X_train), y_train)
# Out:
#       Name  # of inst        Mean  Standard Dev.      FBias  MPE  MAPE  \
# 0  Control       5655 60.40954907    18.49760013 0.02965994 -inf   inf
#
#         RMSE         MAD      WMAPE
# 0 0.22972294 13.40485590 0.22189962

# %% [markdown]
# ### Results

# %%
res_svr_linear
# Out:
#                                           Name  # of inst        Mean  \
# 0  Support Vector Regressor Linear Performance         84 78.79761905
#
#    Standard Dev.      FBias        MPE       MAPE       RMSE         MAD  \
# 0    18.72230791 0.13021311 0.09664306 0.16807856 1.99929417 14.17434206
#
#        WMAPE
# 0 0.17988287

# %%
res_svr_poly
# Out:
#                                               Name  # of inst        Mean  \
# 0  Support Vector Regressor Polynomial Performance         84 78.79761905
#
#    Standard Dev.      FBias         MPE       MAPE       RMSE         MAD  \
# 0    18.72230791 0.05148837 -0.00132018 0.18556557 2.07649982 14.64030061
#
#        WMAPE
# 0 0.18579623

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# ### Grid

# %%
param_grid=[
    {"n_estimators":[200,300,500], "max_features":[8,12,16],
     "bootstrap":[False,True]}
]

# %%
random_reg=RandomForestRegressor()
grid_search = GridSearchCV(estimator=random_reg, param_grid=param_grid,
                 cv=10,return_train_score=True)

# %% [markdown]
# ### Predictions

# %%
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=10, estimator=RandomForestRegressor(),
#              param_grid=[{'bootstrap': [False, True],
#                           'max_features': [8, 12, 16],
#                           'n_estimators': [200, 300, 500]}],
#              return_train_score=True)

# %%
grid_search.best_params_
# Out:
# {'bootstrap': True, 'max_features': 8, 'n_estimators': 300}

# %% [markdown]
# ### Results

# %%
rf_predictions=grid_search.predict(X_test)

# %%
res_rf=performance_list("Random Forest Performance", rf_predictions, y_test)

# %%
res_rf
# Out:
#                         Name  # of inst        Mean  Standard Dev.      FBias  \
# 0  Random Forest Performance         84 78.79761905    18.72230791 0.06545903
#
#          MPE       MAPE       RMSE         MAD      WMAPE
# 0 0.02985421 0.16340055 1.83522218 12.89206349 0.16360981

# %%
performance_list("Control", grid_search.predict(X_train), y_train)
# Out:
#       Name  # of inst        Mean  Standard Dev.       FBias  MPE  MAPE  \
# 0  Control       5655 60.40954907    18.49760013 -0.00018505 -inf   inf
#
#         RMSE        MAD      WMAPE
# 0 0.06621683 3.81430804 0.06314081

# %% [markdown]
# # Feature Extraction

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV
from sklearn import tree

# %% [markdown]
# ### Train Node Selection

# %%
grid_search = DecisionTreeRegressor()

# %%
param_grid_feature = [
{'min_samples_leaf': [5, 7, 10, 15, 20], 'max_depth': [4, 5, 7, 10, 12, 15], 'min_samples_split': [30, 40, 50, 60, 80]}
]

# %%
estimator_best = GridSearchCV(random_search, param_grid_feature, cv=5)

# %%
estimator_best.fit(X_train, y_train, )
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(),
#              param_grid=[{'max_depth': [4, 5, 7, 10, 12, 15],
#                           'min_samples_leaf': [5, 7, 10, 15, 20],
#                           'min_samples_split': [30, 40, 50, 60, 80]}])

# %% [markdown]
# ## Best Parameters

# %%
estimator_best.best_estimator_
# Out:
# DecisionTreeRegressor(max_depth=5, min_samples_leaf=5, min_samples_split=80)

# %% [markdown]
# ### Final Decision Tree

# %%
estimator = DecisionTreeRegressor(max_depth= estimator_best.best_estimator_.max_depth, 
                                  min_impurity_decrease= estimator_best.best_estimator_.min_impurity_decrease,
                                  min_samples_leaf= estimator_best.best_estimator_.min_samples_leaf)

# %%
estimator.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=5, min_samples_leaf=5)

# %%
on_leaf = estimator.apply(X_train)
X_train_ext=X_train[:]
X_train_ext["Node"] = on_leaf.tolist()
# Out:
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
plt.figure(figsize=(14, 8)) 
plt.show(tree.plot_tree(estimator,filled=True, fontsize=8))

# %%
X_train_ext
# Out:
#       snap_CA  snap_TX  snap_WI  sell_price_mean  sell_price_median  \
# 0           0        0        0       5.95971429         5.05000000
# 1           0        0        0       5.95971429         5.05000000
# 2           0        0        0       5.95971429         5.05000000
# 3           1        1        0       5.95971429         5.05000000
# 4           1        0        1       5.95971429         5.05000000
# ...       ...      ...      ...              ...                ...
# 5706        0        0        0       6.46611511         5.47000000
# 5707        0        0        0       6.46611511         5.47000000
# 5708        0        0        0       6.46611511         5.47000000
# 5709        0        0        0       6.46611511         5.47000000
# 5710        0        0        0       6.46611511         5.47000000
#
#       sell_price_std     Friday     Monday   Saturday     Sunday   Thursday  \
# 0         4.09462637 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000
# 1         4.09462637 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000
# 2         4.09462637 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000
# 3         4.09462637 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 4         4.09462637 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# ...              ...        ...        ...        ...        ...        ...
# 5706      5.29861651 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 5707      5.29861651 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000
# 5708      5.29861651 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 5709      5.29861651 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000
# 5710      5.29861651 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000
#
#         Tuesday  Wednesday        Jan        Feb        Mar        Apr  \
# 0    0.00000000 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000
# 1    0.00000000 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000
# 2    0.00000000 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000
# 3    1.00000000 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000
# 4    0.00000000 1.00000000 0.00000000 1.00000000 0.00000000 0.00000000
# ...         ...        ...        ...        ...        ...        ...
# 5706 0.00000000 1.00000000 0.00000000 0.00000000 1.00000000 0.00000000
# 5707 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000
# 5708 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000
# 5709 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000
# 5710 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000
#
#             May       June       July        Agu        Sep        Oct  \
# 0    0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1    0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 2    0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 3    0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 4    0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# ...         ...        ...        ...        ...        ...        ...
# 5706 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 5707 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 5708 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 5709 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 5710 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
#
#             Nov        Dec      _2011      _2012      _2013      _2014  \
# 0    0.00000000 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000
# 1    0.00000000 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000
# 2    0.00000000 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000
# 3    0.00000000 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000
# 4    0.00000000 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000
# ...         ...        ...        ...        ...        ...        ...
# 5706 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 5707 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 5708 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 5709 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 5710 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
#
#           _2015      _2016   Cultural   National  Religious   Sporting  \
# 0    0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1    0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 2    0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 3    0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 4    0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# ...         ...        ...        ...        ...        ...        ...
# 5706 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 5707 0.00000000 1.00000000 0.00000000 0.00000000 1.00000000 0.00000000
# 5708 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 5709 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 5710 0.00000000 1.00000000 1.00000000 0.00000000 0.00000000 0.00000000
#
#            TX_1       TX_2       TX_3  trend  Node
# 0    1.00000000 0.00000000 0.00000000      0    27
# 1    1.00000000 0.00000000 0.00000000      1    13
# 2    1.00000000 0.00000000 0.00000000      2     6
# 3    1.00000000 0.00000000 0.00000000      3     6
# 4    1.00000000 0.00000000 0.00000000      4     6
# ...         ...        ...        ...    ...   ...
# 5706 0.00000000 0.00000000 1.00000000   1880    36
# 5707 0.00000000 0.00000000 1.00000000   1881    36
# 5708 0.00000000 0.00000000 1.00000000   1882    36
# 5709 0.00000000 0.00000000 1.00000000   1883    43
# 5710 0.00000000 0.00000000 1.00000000   1884    57
#
# [5655 rows x 40 columns]

# %% [markdown]
# ### Test Node Selection

# %%
on_leaf_test = estimator.apply(X_test)

# %%
X_test_ext=X_test[:]

# %%
X_test_ext["Node"] = on_leaf_test.tolist()
# Out:
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
X_test_ext
# Out:
#     snap_CA  snap_TX  snap_WI  sell_price_mean  sell_price_median  \
# 0         0        0        0       6.01899225         4.88000000
# 1         0        0        0       6.01899225         4.88000000
# 2         0        0        0       6.01899225         4.88000000
# 3         0        0        0       6.01899225         4.88000000
# 4         1        1        0       6.01899225         4.88000000
# ..      ...      ...      ...              ...                ...
# 79        0        0        0       6.46611511         5.47000000
# 80        0        0        0       6.46611511         5.47000000
# 81        0        0        0       6.46611511         5.47000000
# 82        0        0        0       6.46410072         5.47000000
# 83        0        0        0       6.46410072         5.47000000
#
#     sell_price_std     Friday     Monday   Saturday     Sunday   Thursday  \
# 0       4.40375246 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000
# 1       4.40375246 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 2       4.40375246 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 3       4.40375246 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000
# 4       4.40375246 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# ..             ...        ...        ...        ...        ...        ...
# 79      5.29861651 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 80      5.29861651 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000
# 81      5.29861651 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 82      5.29645832 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000
# 83      5.29645832 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000
#
#       Tuesday  Wednesday        Jan        Feb        Mar        Apr  \
# 0  0.00000000 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000
# 1  1.00000000 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000
# 2  0.00000000 1.00000000 0.00000000 0.00000000 1.00000000 0.00000000
# 3  0.00000000 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000
# 4  0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000
# ..        ...        ...        ...        ...        ...        ...
# 79 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 1.00000000
# 80 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000
# 81 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000
# 82 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000
# 83 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000
#
#           May       June       July        Agu        Sep        Oct  \
# 0  0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1  0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 2  0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 3  0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 4  0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# ..        ...        ...        ...        ...        ...        ...
# 79 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 80 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 81 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 82 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 83 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
#
#           Nov        Dec      _2011      _2012      _2013      _2014  \
# 0  0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1  0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 2  0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 3  0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 4  0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# ..        ...        ...        ...        ...        ...        ...
# 79 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 80 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 81 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 82 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 83 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
#
#         _2015      _2016   Cultural   National  Religious   Sporting  \
# 0  0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1  0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 2  0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 3  0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 4  0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# ..        ...        ...        ...        ...        ...        ...
# 79 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 80 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 81 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 82 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 83 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000
#
#          TX_1       TX_2       TX_3  trend  Node
# 0  1.00000000 0.00000000 0.00000000   1885    35
# 1  1.00000000 0.00000000 0.00000000   1886    35
# 2  1.00000000 0.00000000 0.00000000   1887    35
# 3  1.00000000 0.00000000 0.00000000   1888    35
# 4  1.00000000 0.00000000 0.00000000   1889    35
# ..        ...        ...        ...    ...   ...
# 79 0.00000000 0.00000000 1.00000000   1908    36
# 80 0.00000000 0.00000000 1.00000000   1909    36
# 81 0.00000000 0.00000000 1.00000000   1910    36
# 82 0.00000000 0.00000000 1.00000000   1911    43
# 83 0.00000000 0.00000000 1.00000000   1912    57
#
# [84 rows x 40 columns]

# %% [markdown]
# ### Feature Adding

# %% [markdown]
# Ma=1 kullanıldı daha hızlı bir şekilde anlaşılması için

# %%
Xframes_feature=[X_train_ext, X_test_ext]
yframes_feature=[y_train, y_test]
X_concat=pd.concat(Xframes_feature)
Y_concat=pd.concat(yframes_feature)
final_frame=[X_concat, Y_concat]
concated_df=pd.concat(final_frame, axis=1)

# %%
concated_df["new_feature"] = concated_df.groupby(["Node"])["Sales"].shift(+1)

# %% [markdown]
# # Feature Control

# %%
concated_df["Node"].value_counts()
# Out:
# 32    1608
# 6      787
# 35     652
# 33     402
# 36     326
# 39     314
# 13     177
# 47     165
# 48     152
# 5      146
# 57     129
# 8      116
# 42     103
# 43     101
# 40      82
# 19      69
# 50      65
# 26      60
# 9       58
# 54      54
# 27      54
# 12      39
# 23      23
# 51      17
# 58      12
# 20       6
# 55       6
# 14       6
# 24       5
# 18       5
# Name: Node, dtype: int64

# %%
concated_df[-28:].Node
# Out:
# 56    36
# 57    36
# 58    36
# 59    36
# 60    36
# 61    43
# 62    57
# 63    36
# 64    36
# 65    36
# 66    36
# 67    36
# 68    43
# 69    57
# 70    36
# 71    36
# 72    36
# 73    36
# 74    36
# 75    43
# 76    57
# 77    36
# 78    36
# 79    36
# 80    36
# 81    36
# 82    43
# 83    57
# Name: Node, dtype: int64

# %% [markdown]
# ## New Feature Adding to Test Set

# %%
for i in list(range(0,28)):
    current_node=concated_df.iloc[-(28-i)].Node
    train_dt=concated_df.iloc[:-28]
    new_value=train_dt[train_dt["Node"]==int(current_node)].iloc[-1].Sales
    concated_df.iloc[-(28-i),concated_df.shape[1]-1]=new_value

# %%
X_test_new=concated_df.iloc[len(X_train):].drop(["Sales","Node"], axis=1)

y_test_new=concated_df.iloc[len(X_train):]["Sales"]

# %%
train_new=concated_df.iloc[:len(X_train)]

# %%
train_new.dropna(inplace=True);
train_new.reset_index(drop=True, inplace=True)
# Out:
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
X_train_new=train_new.drop(["Sales","Node"], axis=1)

y_train_new=train_new["Sales"]

# %% [markdown]
# # Linear Regression-Elastic Net

# %% [markdown]
# ### Grid

# %%
elastic_net_model_new = ElasticNet()

# %%
param_grid_elastic=[
    {"alpha":[0.1,0.2,0.3,0.4], "l1_ratio":[0.2,0.4,0.6]}
]

# %%
elastic_net_new = GridSearchCV(estimator=elastic_net_model_new, param_grid=param_grid_elastic,
                 cv=10,return_train_score=True)

# %%
elastic_net_new.fit(X_train_new, y_train_new)
# Out:
# GridSearchCV(cv=10, estimator=ElasticNet(),
#              param_grid=[{'alpha': [0.1, 0.2, 0.3, 0.4],
#                           'l1_ratio': [0.2, 0.4, 0.6]}],
#              return_train_score=True)

# %%
elastic_predictions_new=elastic_net_new.predict(X_test_new)

# %%
res_elastic_new=performance_list("Elastic Net Performance with Feature Extraction", elastic_predictions_new, y_test_new)

# %%
res_elastic_new
# Out:
#                                               Name  # of inst        Mean  \
# 0  Elastic Net Performance with Feature Extraction         84 78.79761905
#
#    Standard Dev.      FBias        MPE       MAPE       RMSE         MAD  \
# 0    18.72230791 0.07249924 0.03542625 0.15722413 1.76415058 12.78923289
#
#        WMAPE
# 0 0.16230481

# %% [markdown]
# ### SVM

# %% [markdown]
# #### Linear

# %%
sv_regressor_new=LinearSVR()

# %% [markdown]
# ### Grid

# %%
param_grid_svm_linear=[
    {"epsilon":[0.5,1,1.5]}
]

# %%
sv_regressor_new = GridSearchCV(estimator=sv_regressor_new, param_grid=param_grid_svm_linear,
                 cv=10,return_train_score=True,)

# %%
sv_regressor_new.fit(X_train_new, y_train_new)
# Out:
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# GridSearchCV(cv=10, estimator=LinearSVR(),
#              param_grid=[{'epsilon': [0.5, 1, 1.5]}], return_train_score=True)

# %%
svm_predictions_new=sv_regressor_new.predict(X_test_new)

res_svr_new=performance_list("SVR Linear Performance with Feature Extraction", 
                                svm_predictions_new, y_test_new)

res_svr_new
# Out:
#                                              Name  # of inst        Mean  \
# 0  SVR Linear Performance with Feature Extraction         84 78.79761905
#
#    Standard Dev.      FBias        MPE       MAPE       RMSE         MAD  \
# 0    18.72230791 0.16578436 0.13332065 0.18161492 2.19400444 15.64074121
#
#        WMAPE
# 0 0.19849256

# %% [markdown]
# ## Poly

# %% [markdown]
# ### Grid

# %%
param_grid_svm_poly=[
    {"degree":[2,3,4], "epsilon":[0.02,0.05, 0.1, 0.15, 0.2]}
]

# %%
sv_regressor_poly_new=SVR(kernel="poly")

# %%
sv_regressor_poly_new = GridSearchCV(estimator=sv_regressor_poly_new, param_grid=param_grid_svm_poly,
                 cv=10,return_train_score=True)

# %%
sv_regressor_poly_new.fit(X_train_new, y_train_new)
# Out:
# GridSearchCV(cv=10, estimator=SVR(kernel='poly'),
#              param_grid=[{'degree': [2, 3, 4],
#                           'epsilon': [0.02, 0.05, 0.1, 0.15, 0.2]}],
#              return_train_score=True)

# %%
sv_regressor_poly_new.best_estimator_
# Out:
# SVR(epsilon=0.2, kernel='poly')

# %%
svm_predictions_poly_new=sv_regressor_poly_new.predict(X_test_new)

res_svr_poly_new=performance_list("SVR Polynomail Performance with Feature Extraction", 
                                svm_predictions_poly_new, y_test_new)

res_svr_poly_new
# Out:
#                                                 Name  # of inst        Mean  \
# 0  SVR Polynomail Performance with Feature Extrac...         84 78.79761905
#
#    Standard Dev.      FBias         MPE       MAPE       RMSE         MAD  \
# 0    18.72230791 0.03364722 -0.01571164 0.18271616 1.93792692 14.21170265
#
#        WMAPE
# 0 0.18035701

# %% [markdown]
# ### Random Forest

# %%
param_grid=[
    {"n_estimators":[200,300,500], "max_features":[8,12,16],
     "bootstrap":[False,True]}
]

# %%
random_reg_new=RandomForestRegressor()
grid_search_new = GridSearchCV(estimator=random_reg_new, param_grid=param_grid,
                 cv=10,return_train_score=True)

# %%
grid_search_new.fit(X_train_new, y_train_new)

grid_search_new.best_params_
# Out:
# {'bootstrap': True, 'max_features': 8, 'n_estimators': 200}

# %%
rf_predictions_new=grid_search_new.predict(X_test_new)

res_rf_new=performance_list("Random Forest Performance with Feature Extraction", rf_predictions_new, y_test_new)

res_rf_new
# Out:
#                                                 Name  # of inst        Mean  \
# 0  Random Forest Performance with Feature Extraction         84 78.79761905
#
#    Standard Dev.      FBias        MPE       MAPE       RMSE         MAD  \
# 0    18.72230791 0.07963627 0.04298293 0.16269559 1.86167446 13.10252976
#
#        WMAPE
# 0 0.16628078

# %% [markdown]
# # General Result Table

# %%
pd.options.display.float_format = '{:,.8f}'.format

# %%
result_frames=[res_elastic,res_svr_linear,res_svr_poly,res_rf, res_elastic_new,res_svr_new,res_svr_poly_new,res_rf_new]
total_result=pd.concat(result_frames)
total_result.reset_index(drop=True, inplace=True)

# %%
total_result
# Out:
#                                                 Name  # of inst        Mean  \
# 0                            Elastic Net Performance         84 78.79761905
# 1        Support Vector Regressor Linear Performance         84 78.79761905
# 2    Support Vector Regressor Polynomial Performance         84 78.79761905
# 3                          Random Forest Performance         84 78.79761905
# 4    Elastic Net Performance with Feature Extraction         84 78.79761905
# 5     SVR Linear Performance with Feature Extraction         84 78.79761905
# 6  SVR Polynomail Performance with Feature Extrac...         84 78.79761905
# 7  Random Forest Performance with Feature Extraction         84 78.79761905
#
#    Standard Dev.      FBias         MPE       MAPE       RMSE         MAD  \
# 0    18.72230791 0.08416746  0.04703632 0.15450885 1.78080546 12.61592555
# 1    18.72230791 0.13021311  0.09664306 0.16807856 1.99929417 14.17434206
# 2    18.72230791 0.05148837 -0.00132018 0.18556557 2.07649982 14.64030061
# 3    18.72230791 0.06545903  0.02985421 0.16340055 1.83522218 12.89206349
# 4    18.72230791 0.07249924  0.03542625 0.15722413 1.76415058 12.78923289
# 5    18.72230791 0.16578436  0.13332065 0.18161492 2.19400444 15.64074121
# 6    18.72230791 0.03364722 -0.01571164 0.18271616 1.93792692 14.21170265
# 7    18.72230791 0.07963627  0.04298293 0.16269559 1.86167446 13.10252976
#
#        WMAPE
# 0 0.16010542
# 1 0.17988287
# 2 0.18579623
# 3 0.16360981
# 4 0.16230481
# 5 0.19849256
# 6 0.18035701
# 7 0.16628078

# %% [markdown]
# ## RFOverfitting

# %%
rf_control=grid_search.predict(X_train)

performance_list("RF Performance without Feature Extraction",rf_control, y_train)
# Out:
#                                         Name  # of inst        Mean  \
# 0  RF Performance without Feature Extraction       5655 60.40954907
#
#    Standard Dev.       FBias  MPE  MAPE       RMSE        MAD      WMAPE
# 0    18.49760013 -0.00018505 -inf   inf 0.06621683 3.81430804 0.06314081

# %%
rf_control=grid_search.predict(X_test)

performance_list("RF Performance without Feature Extraction",rf_control, y_test)
# Out:
#                                         Name  # of inst        Mean  \
# 0  RF Performance without Feature Extraction         84 78.79761905
#
#    Standard Dev.      FBias        MPE       MAPE       RMSE         MAD  \
# 0    18.72230791 0.06545903 0.02985421 0.16340055 1.83522218 12.89206349
#
#        WMAPE
# 0 0.16360981

# %%
rf_control_feature=grid_search_new.predict(X_train_new)

performance_list("RF Performance with Feature Extraction", rf_control_feature, y_train_new)
# Out:
#                                      Name  # of inst        Mean  \
# 0  RF Performance with Feature Extraction       5424 60.15929204
#
#    Standard Dev.       FBias  MPE  MAPE       RMSE        MAD      WMAPE
# 0    18.29945537 -0.00043890 -inf   inf 0.06587532 3.71789128 0.06180078

# %%
rf_control_feature=grid_search_new.predict(X_test_new)

performance_list("RF Performance with Feature Extraction", rf_control_feature, y_test_new)
# Out:
#                                      Name  # of inst        Mean  \
# 0  RF Performance with Feature Extraction         84 78.79761905
#
#    Standard Dev.      FBias        MPE       MAPE       RMSE         MAD  \
# 0    18.72230791 0.07963627 0.04298293 0.16269559 1.86167446 13.10252976
#
#        WMAPE
# 0 0.16628078

# %% [markdown]
# # Feature Control

# %%
plt.plot(data.Sales[:28])

# %%
from statsmodels.graphics.tsaplots import plot_acf

# %%
plot_acf(data.Sales, lags=28)
plt.show()

# %% [markdown]
# ## Node Control

# %%
concated_df.Node.value_counts()
# Out:
# 207    414
# 261    322
# 31     229
# 192    226
# 217    192
#       ...
# 342      5
# 232      5
# 414      5
# 418      5
# 459      5
# Name: Node, Length: 231, dtype: int64

# %%
total_result
# Out:
#                                                 Name  # of inst        Mean  \
# 0                            Elastic Net Performance         84 78.79761905
# 1        Support Vector Regressor Linear Performance         84 78.79761905
# 2    Support Vector Regressor Polynomial Performance         84 78.79761905
# 3                          Random Forest Performance         84 78.79761905
# 4    Elastic Net Performance with Feature Extraction         84 78.79761905
# 5     SVR Linear Performance with Feature Extraction         84 78.79761905
# 6  SVR Polynomail Performance with Feature Extrac...         84 78.79761905
# 7  Random Forest Performance with Feature Extraction         84 78.79761905
#
#    Standard Dev.      FBias         MPE       MAPE       RMSE         MAD  \
# 0    18.72230791 0.08416746  0.04703632 0.15450885 1.78080546 12.61592555
# 1    18.72230791 0.13021311  0.09664306 0.16807856 1.99929417 14.17434206
# 2    18.72230791 0.05148837 -0.00132018 0.18556557 2.07649982 14.64030061
# 3    18.72230791 0.06545903  0.02985421 0.16340055 1.83522218 12.89206349
# 4    18.72230791 0.07249924  0.03542625 0.15722413 1.76415058 12.78923289
# 5    18.72230791 0.16578436  0.13332065 0.18161492 2.19400444 15.64074121
# 6    18.72230791 0.03364722 -0.01571164 0.18271616 1.93792692 14.21170265
# 7    18.72230791 0.07963627  0.04298293 0.16269559 1.86167446 13.10252976
#
#        WMAPE
# 0 0.16010542
# 1 0.17988287
# 2 0.18579623
# 3 0.16360981
# 4 0.16230481
# 5 0.19849256
# 6 0.18035701
# 7 0.16628078

# %% [markdown]
# # General Function

# %%
# def result_obtain(df, feature_set, name, lag):

#     df[name]=feature_set
    
# #     train=df[df["date"]<((df["date"].max()-df["date"].min())*0.8)+df["date"].min()]
# #     test=df[df["date"]>=((df["date"].max()-df["date"].min())*0.8)+df["date"].min()]
# #     test.reset_index(drop=True, inplace=True)

#     train=data[data["date"]<=specific_date]

#     test=data[data["date"]>specific_date]
#     test.reset_index(drop=True, inplace=True)


#     ### Date and Customer Drop

#     train=train.drop(["date"], axis=1)
#     test=test.drop(["date"], axis=1)

#     X_train, y_train=train.drop(["Sales"], axis=1), train["Sales"]
#     X_test, y_test=test.drop(["Sales"], axis=1), test["Sales"]
    
#     train.dropna(inplace=True);
#     train.reset_index(drop=True, inplace=True)
#     train.index += lag

#     X_train, y_train=train.drop(["Sales"], axis=1), train["Sales"]
#     X_test, y_test=test.drop(["Sales"], axis=1), test["Sales"]
    
    
    
#     # Linear Regression-Elastic Net

#     elastic_net_function = ElasticNet()

#     param_grid_elastic=[
#         {"alpha":[0.1,0.2,0.3,0.4], "l1_ratio":[0.2,0.4,0.6]}
#     ]

#     elastic_net_function = GridSearchCV(estimator=elastic_net_function, param_grid=param_grid_elastic,
#                      cv=10,return_train_score=True)
    
#     elastic_net_function.fit(X_train, y_train)
    

#     elastic_predictions=elastic_net_function.predict(X_test)

#     res_elastic=performance_list(["Elastic Net Performance Lag " + str(lag)], elastic_predictions, y_test)

    
    
#     # Support Vector Machines

#     ### Linear

#     sv_regressor=LinearSVR()
    

#     ### Grid

#     param_grid_svm_linear=[
#         {"epsilon":[0.5,1,1.5]}
#     ]

#     sv_regressor_function = GridSearchCV(estimator=sv_regressor, param_grid=param_grid_svm_linear,
#                      cv=10,return_train_score=True)

#     sv_regressor_function.fit(X_train, y_train)


    
#     sv_regressor_poly=SVR(kernel="poly")
        
#     ### Grid

#     param_grid_svm_poly=[
#         {"degree":[2,3], "epsilon":[0.02,0.05, 0.1, 0.15, 0.2]}
#     ]


#     sv_regressor_poly_function = GridSearchCV(estimator=sv_regressor_poly, param_grid=param_grid_svm_poly,
#                      cv=10,return_train_score=True)

#     sv_regressor_poly_function.fit(X_train, y_train)


#     ### Predictions

#     svm_predictions_linear=sv_regressor_function.predict(X_test)
    
#     svm_predictions_poly=sv_regressor_poly_function.predict(X_test)


#     ### Results    

#     res_svr_poly=performance_list(["SVR Polynomial Performance Lag " + str(lag)], svm_predictions_poly, y_test)

#     res_svr_linear=performance_list(["SVR Linear Performance Lag " + str(lag)], svm_predictions_linear, y_test)

    
    
    
#     # Random Forest
    
#     ### Grid

#     param_grid=[
#         {"n_estimators":[200,300,500], "max_features":[8,12,16],
#          "bootstrap":[False,True]}
#     ]

#     random_reg_function=RandomForestRegressor()
#     grid_search = GridSearchCV(estimator=random_reg_function, param_grid=param_grid,
#                      cv=10,return_train_score=True)

#     ### Predictions

#     grid_search.fit(X_train, y_train)

#     ### Results

#     rf_predictions=grid_search.predict(X_test)

#     res_rf=performance_list(["Random Forest Performance Lag " + str(lag)], rf_predictions, y_test)
    
#     res_df=[res_elastic, res_svr_linear, res_svr_poly, res_rf]

#     total_res=pd.concat(res_df)
    
#     return total_res

# %%
# res1=result_obtain(data.copy(), data["Sales"].shift(+1), "lag1", 1)

# %%
# res1

# %%
# total_result
