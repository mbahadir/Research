# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\bahad\\GitHub\\Research\\Models'

# %%
pd.set_option("display.max_columns", None)

# %% [markdown]
# # Data Loading

# %%
data_initial=pd.read_csv("D:/Datasets/m5-forecasting-accuracy/Obtained_Data/first_scenario_group.csv",dtype={"event_name_1": object,
                                                                                         "event_type_1": object,
                                                                                         "event_name_2": object,
                                                                                         "event_type_2": object,},index_col=0)

# %%
data_initial["date"]=pd.to_datetime(data_initial["date"])

# %%
data_initial.sort_values(["date"])
# Out:
#            date  Sales event_name_1 event_type_1 event_name_2 event_type_2  \
# 0    2011-01-29     58          NaN          NaN          NaN          NaN
# 1    2011-01-30     62          NaN          NaN          NaN          NaN
# 2    2011-01-31     41          NaN          NaN          NaN          NaN
# 3    2011-02-01     46          NaN          NaN          NaN          NaN
# 4    2011-02-02     28          NaN          NaN          NaN          NaN
# ...         ...    ...          ...          ...          ...          ...
# 1908 2016-04-20     79          NaN          NaN          NaN          NaN
# 1909 2016-04-21     71          NaN          NaN          NaN          NaN
# 1910 2016-04-22     81          NaN          NaN          NaN          NaN
# 1911 2016-04-23     69          NaN          NaN          NaN          NaN
# 1912 2016-04-24     72          NaN          NaN          NaN          NaN
#
#       snap_CA  snap_TX  snap_WI  sell_price_mean  sell_price_median  \
# 0           0        0        0       5.95971429         5.05000000
# 1           0        0        0       5.95971429         5.05000000
# 2           0        0        0       5.95971429         5.05000000
# 3           1        1        0       5.95971429         5.05000000
# 4           1        0        1       5.95971429         5.05000000
# ...       ...      ...      ...              ...                ...
# 1908        0        0        0       6.01899225         4.88000000
# 1909        0        0        0       6.01899225         4.88000000
# 1910        0        0        0       6.01899225         4.88000000
# 1911        0        0        0       6.01899225         4.88000000
# 1912        0        0        0       6.01899225         4.88000000
#
#       sell_price_std         CA         TX         WI     Friday     Monday  \
# 0         4.09462637 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000
# 1         4.09462637 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000
# 2         4.09462637 0.00000000 1.00000000 0.00000000 0.00000000 1.00000000
# 3         4.09462637 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000
# 4         4.09462637 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000
# ...              ...        ...        ...        ...        ...        ...
# 1908      4.40375246 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000
# 1909      4.40375246 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000
# 1910      4.40375246 0.00000000 1.00000000 0.00000000 1.00000000 0.00000000
# 1911      4.40375246 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000
# 1912      4.40375246 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000
#
#        Saturday     Sunday   Thursday    Tuesday  Wednesday        Jan  \
# 0    1.00000000 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000
# 1    0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 1.00000000
# 2    0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000
# 3    0.00000000 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000
# 4    0.00000000 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000
# ...         ...        ...        ...        ...        ...        ...
# 1908 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000
# 1909 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000
# 1910 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1911 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1912 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000
#
#             Feb        Mar        Apr        May       June       July  \
# 0    0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1    0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 2    0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 3    1.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 4    1.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# ...         ...        ...        ...        ...        ...        ...
# 1908 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000
# 1909 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000
# 1910 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000
# 1911 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000
# 1912 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000
#
#             Agu        Sep        Oct        Nov        Dec      _2011  \
# 0    0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000
# 1    0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000
# 2    0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000
# 3    0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000
# 4    0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000
# ...         ...        ...        ...        ...        ...        ...
# 1908 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1909 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1910 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1911 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1912 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
#
#           _2012      _2013      _2014      _2015      _2016
# 0    0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1    0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 2    0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 3    0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 4    0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# ...         ...        ...        ...        ...        ...
# 1908 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000
# 1909 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000
# 1910 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000
# 1911 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000
# 1912 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000
#
# [1913 rows x 40 columns]

# %%
plt.plot(data_initial.Sales)

# %% [markdown]
# ## Event Conversion

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
hot_encoder=OneHotEncoder()

# %%
data_initial.drop(["event_name_1", "event_name_2", "event_type_2", "CA", "TX", "WI"], axis=1, inplace=True)

# %%
data_initial[data_initial["event_type_1"].isna()]["event_type_1"]=0
data_initial["event_type_1"]=data_initial["event_type_1"].astype(str)
# Out:
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
encoded_event=hot_encoder.fit_transform(data_initial[["event_type_1"]])
array_event=encoded_event.toarray()

# %%
hot_encoder.categories_
# Out:
# [array(['Cultural', 'National', 'Religious', 'Sporting', 'nan'],
#        dtype=object)]

# %%
event_df=pd.DataFrame(array_event,columns=["Cultural", "National", "Religious", "Sporting", 'nan'])

# %%
frames=[data_initial, event_df]
data=pd.concat(frames, axis=1)

# %%
data.drop(["event_type_1", "nan"], axis=1, inplace=True)

# %%
data.head()
# Out:
#         date  Sales  snap_CA  snap_TX  snap_WI  sell_price_mean  \
# 0 2011-01-29     58        0        0        0       5.95971429
# 1 2011-01-30     62        0        0        0       5.95971429
# 2 2011-01-31     41        0        0        0       5.95971429
# 3 2011-02-01     46        1        1        0       5.95971429
# 4 2011-02-02     28        1        0        1       5.95971429
#
#    sell_price_median  sell_price_std     Friday     Monday   Saturday  \
# 0         5.05000000      4.09462637 0.00000000 0.00000000 1.00000000
# 1         5.05000000      4.09462637 0.00000000 0.00000000 0.00000000
# 2         5.05000000      4.09462637 0.00000000 1.00000000 0.00000000
# 3         5.05000000      4.09462637 0.00000000 0.00000000 0.00000000
# 4         5.05000000      4.09462637 0.00000000 0.00000000 0.00000000
#
#       Sunday   Thursday    Tuesday  Wednesday        Jan        Feb  \
# 0 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000
# 1 1.00000000 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000
# 2 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000
# 3 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000 1.00000000
# 4 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000 1.00000000
#
#          Mar        Apr        May       June       July        Agu  \
# 0 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 2 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 3 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 4 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
#
#          Sep        Oct        Nov        Dec      _2011      _2012  \
# 0 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000
# 1 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000
# 2 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000
# 3 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000
# 4 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000
#
#        _2013      _2014      _2015      _2016   Cultural   National  \
# 0 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 2 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 3 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 4 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
#
#    Religious   Sporting
# 0 0.00000000 0.00000000
# 1 0.00000000 0.00000000
# 2 0.00000000 0.00000000
# 3 0.00000000 0.00000000
# 4 0.00000000 0.00000000

# %%
data.describe()
# Out:
#                Sales        snap_CA        snap_TX        snap_WI  \
# count 1,913.00000000 1,913.00000000 1,913.00000000 1,913.00000000
# mean     57.98954522     0.32932567     0.32932567     0.32932567
# std      17.53916405     0.47009126     0.47009126     0.47009126
# min       0.00000000     0.00000000     0.00000000     0.00000000
# 25%      46.00000000     0.00000000     0.00000000     0.00000000
# 50%      56.00000000     0.00000000     0.00000000     0.00000000
# 75%      69.00000000     1.00000000     1.00000000     1.00000000
# max     147.00000000     1.00000000     1.00000000     1.00000000
#
#        sell_price_mean  sell_price_median  sell_price_std         Friday  \
# count   1,913.00000000     1,913.00000000  1,913.00000000 1,913.00000000
# mean        6.10063961         5.00181390      4.34306677     0.14270779
# std         0.14825859         0.12984362      0.18432923     0.34986606
# min         5.80757576         4.88000000      3.95982925     0.00000000
# 25%         6.02116279         4.88000000      4.15823830     0.00000000
# 50%         6.06713178         4.93000000      4.43752009     0.00000000
# 75%         6.16666667         5.12000000      4.46365805     0.00000000
# max         6.46042735         5.32000000      4.61049840     1.00000000
#
#               Monday       Saturday         Sunday       Thursday  \
# count 1,913.00000000 1,913.00000000 1,913.00000000 1,913.00000000
# mean      0.14270779     0.14323053     0.14323053     0.14270779
# std       0.34986606     0.35039938     0.35039938     0.34986606
# min       0.00000000     0.00000000     0.00000000     0.00000000
# 25%       0.00000000     0.00000000     0.00000000     0.00000000
# 50%       0.00000000     0.00000000     0.00000000     0.00000000
# 75%       0.00000000     0.00000000     0.00000000     0.00000000
# max       1.00000000     1.00000000     1.00000000     1.00000000
#
#              Tuesday      Wednesday            Jan            Feb  \
# count 1,913.00000000 1,913.00000000 1,913.00000000 1,913.00000000
# mean      0.14270779     0.14270779     0.08259279     0.08886566
# std       0.34986606     0.34986606     0.27533770     0.28462414
# min       0.00000000     0.00000000     0.00000000     0.00000000
# 25%       0.00000000     0.00000000     0.00000000     0.00000000
# 50%       0.00000000     0.00000000     0.00000000     0.00000000
# 75%       0.00000000     0.00000000     0.00000000     0.00000000
# max       1.00000000     1.00000000     1.00000000     1.00000000
#
#                  Mar            Apr            May           June  \
# count 1,913.00000000 1,913.00000000 1,913.00000000 1,913.00000000
# mean      0.09722948     0.09095661     0.08102457     0.07841087
# std       0.29634746     0.28762259     0.27294419     0.26888734
# min       0.00000000     0.00000000     0.00000000     0.00000000
# 25%       0.00000000     0.00000000     0.00000000     0.00000000
# 50%       0.00000000     0.00000000     0.00000000     0.00000000
# 75%       0.00000000     0.00000000     0.00000000     0.00000000
# max       1.00000000     1.00000000     1.00000000     1.00000000
#
#                 July            Agu            Sep            Oct  \
# count 1,913.00000000 1,913.00000000 1,913.00000000 1,913.00000000
# mean      0.08102457     0.08102457     0.07841087     0.08102457
# std       0.27294419     0.27294419     0.26888734     0.27294419
# min       0.00000000     0.00000000     0.00000000     0.00000000
# 25%       0.00000000     0.00000000     0.00000000     0.00000000
# 50%       0.00000000     0.00000000     0.00000000     0.00000000
# 75%       0.00000000     0.00000000     0.00000000     0.00000000
# max       1.00000000     1.00000000     1.00000000     1.00000000
#
#                  Nov            Dec          _2011          _2012  \
# count 1,913.00000000 1,913.00000000 1,913.00000000 1,913.00000000
# mean      0.07841087     0.08102457     0.17616309     0.19132253
# std       0.26888734     0.27294419     0.38105848     0.39344522
# min       0.00000000     0.00000000     0.00000000     0.00000000
# 25%       0.00000000     0.00000000     0.00000000     0.00000000
# 50%       0.00000000     0.00000000     0.00000000     0.00000000
# 75%       0.00000000     0.00000000     0.00000000     0.00000000
# max       1.00000000     1.00000000     1.00000000     1.00000000
#
#                _2013          _2014          _2015          _2016  \
# count 1,913.00000000 1,913.00000000 1,913.00000000 1,913.00000000
# mean      0.19079979     0.19079979     0.19079979     0.06011500
# std       0.39303433     0.39303433     0.39303433     0.23776194
# min       0.00000000     0.00000000     0.00000000     0.00000000
# 25%       0.00000000     0.00000000     0.00000000     0.00000000
# 50%       0.00000000     0.00000000     0.00000000     0.00000000
# 75%       0.00000000     0.00000000     0.00000000     0.00000000
# max       1.00000000     1.00000000     1.00000000     1.00000000
#
#             Cultural       National      Religious       Sporting
# count 1,913.00000000 1,913.00000000 1,913.00000000 1,913.00000000
# mean      0.01829587     0.02665970     0.02718244     0.00836383
# std       0.13405419     0.16112892     0.16265725     0.09109451
# min       0.00000000     0.00000000     0.00000000     0.00000000
# 25%       0.00000000     0.00000000     0.00000000     0.00000000
# 50%       0.00000000     0.00000000     0.00000000     0.00000000
# 75%       0.00000000     0.00000000     0.00000000     0.00000000
# max       1.00000000     1.00000000     1.00000000     1.00000000

# %% [markdown]
# # Performance Function

# %%
def performance_list(ID,actual,forecast):
    name=ID
    n=len(actual)
    error=actual-forecast
    mean=np.mean(actual)
    sd=actual.std()
    FBias=sum(error)/sum(actual)
    MPE=sum(error/actual)/n
    MAPE=sum(abs(error/actual))/n
    RMSE=np.sqrt(sum(error**2))/n
    MAD=sum(abs(error))/n
    WMAPE=MAD/mean
    result_df=pd.DataFrame({"Name" :       name ,
                            "# of inst":       n,
                            "Mean":         mean,
                            "Standard Dev.":  sd, 
                            "FBias":       FBias, 
                            "MPE":           MPE, 
                            "MAPE":         MAPE,                                      
                            "RMSE":         RMSE, 
                            "MAD":           MAD, 
                            "WMAPE":      WMAPE}, index=[0])
    return(result_df)

# %% [markdown]
# # Visual Control

# %%
plt.plot(data["Sales"])

# %%
data[:-28]
# Out:
#            date  Sales  snap_CA  snap_TX  snap_WI  sell_price_mean  \
# 0    2011-01-29     58        0        0        0       5.95971429
# 1    2011-01-30     62        0        0        0       5.95971429
# 2    2011-01-31     41        0        0        0       5.95971429
# 3    2011-02-01     46        1        1        0       5.95971429
# 4    2011-02-02     28        1        0        1       5.95971429
# ...         ...    ...      ...      ...      ...              ...
# 1880 2016-03-23     41        0        0        0       6.01875969
# 1881 2016-03-24     55        0        0        0       6.01875969
# 1882 2016-03-25     73        0        0        0       6.01875969
# 1883 2016-03-26     78        0        0        0       6.01899225
# 1884 2016-03-27     80        0        0        0       6.01899225
#
#       sell_price_median  sell_price_std     Friday     Monday   Saturday  \
# 0            5.05000000      4.09462637 0.00000000 0.00000000 1.00000000
# 1            5.05000000      4.09462637 0.00000000 0.00000000 0.00000000
# 2            5.05000000      4.09462637 0.00000000 1.00000000 0.00000000
# 3            5.05000000      4.09462637 0.00000000 0.00000000 0.00000000
# 4            5.05000000      4.09462637 0.00000000 0.00000000 0.00000000
# ...                 ...             ...        ...        ...        ...
# 1880         4.88000000      4.40403739 0.00000000 0.00000000 0.00000000
# 1881         4.88000000      4.40403739 0.00000000 0.00000000 0.00000000
# 1882         4.88000000      4.40403739 1.00000000 0.00000000 0.00000000
# 1883         4.88000000      4.40375246 0.00000000 0.00000000 1.00000000
# 1884         4.88000000      4.40375246 0.00000000 0.00000000 0.00000000
#
#          Sunday   Thursday    Tuesday  Wednesday        Jan        Feb  \
# 0    0.00000000 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000
# 1    1.00000000 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000
# 2    0.00000000 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000
# 3    0.00000000 0.00000000 1.00000000 0.00000000 0.00000000 1.00000000
# 4    0.00000000 0.00000000 0.00000000 1.00000000 0.00000000 1.00000000
# ...         ...        ...        ...        ...        ...        ...
# 1880 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000
# 1881 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1882 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1883 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1884 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
#
#             Mar        Apr        May       June       July        Agu  \
# 0    0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1    0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 2    0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 3    0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 4    0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# ...         ...        ...        ...        ...        ...        ...
# 1880 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1881 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1882 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1883 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1884 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
#
#             Sep        Oct        Nov        Dec      _2011      _2012  \
# 0    0.00000000 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000
# 1    0.00000000 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000
# 2    0.00000000 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000
# 3    0.00000000 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000
# 4    0.00000000 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000
# ...         ...        ...        ...        ...        ...        ...
# 1880 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1881 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1882 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1883 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1884 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
#
#           _2013      _2014      _2015      _2016   Cultural   National  \
# 0    0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1    0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 2    0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 3    0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 4    0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# ...         ...        ...        ...        ...        ...        ...
# 1880 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000
# 1881 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000
# 1882 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000
# 1883 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000
# 1884 0.00000000 0.00000000 0.00000000 1.00000000 1.00000000 0.00000000
#
#       Religious   Sporting
# 0    0.00000000 0.00000000
# 1    0.00000000 0.00000000
# 2    0.00000000 0.00000000
# 3    0.00000000 0.00000000
# 4    0.00000000 0.00000000
# ...         ...        ...
# 1880 0.00000000 0.00000000
# 1881 1.00000000 0.00000000
# 1882 0.00000000 0.00000000
# 1883 0.00000000 0.00000000
# 1884 0.00000000 0.00000000
#
# [1885 rows x 37 columns]

# %%
data[-28:]
# Out:
#            date  Sales  snap_CA  snap_TX  snap_WI  sell_price_mean  \
# 1885 2016-03-28     60        0        0        0       6.01899225
# 1886 2016-03-29     65        0        0        0       6.01899225
# 1887 2016-03-30     60        0        0        0       6.01899225
# 1888 2016-03-31     82        0        0        0       6.01899225
# 1889 2016-04-01     83        1        1        0       6.01899225
# 1890 2016-04-02    133        1        0        1       6.01899225
# 1891 2016-04-03     61        1        1        1       6.01899225
# 1892 2016-04-04     66        1        0        0       6.01899225
# 1893 2016-04-05     69        1        1        1       6.01899225
# 1894 2016-04-06     59        1        1        1       6.01899225
# 1895 2016-04-07     44        1        1        0       6.01899225
# 1896 2016-04-08     93        1        0        1       6.01899225
# 1897 2016-04-09     83        1        1        1       6.01899225
# 1898 2016-04-10     89        1        0        0       6.01899225
# 1899 2016-04-11     59        0        1        1       6.01899225
# 1900 2016-04-12     50        0        1        1       6.01899225
# 1901 2016-04-13     57        0        1        0       6.01899225
# 1902 2016-04-14     65        0        0        1       6.01899225
# 1903 2016-04-15     72        0        1        1       6.01899225
# 1904 2016-04-16     73        0        0        0       6.01899225
# 1905 2016-04-17     94        0        0        0       6.01899225
# 1906 2016-04-18     82        0        0        0       6.01899225
# 1907 2016-04-19     64        0        0        0       6.01899225
# 1908 2016-04-20     79        0        0        0       6.01899225
# 1909 2016-04-21     71        0        0        0       6.01899225
# 1910 2016-04-22     81        0        0        0       6.01899225
# 1911 2016-04-23     69        0        0        0       6.01899225
# 1912 2016-04-24     72        0        0        0       6.01899225
#
#       sell_price_median  sell_price_std     Friday     Monday   Saturday  \
# 1885         4.88000000      4.40375246 0.00000000 1.00000000 0.00000000
# 1886         4.88000000      4.40375246 0.00000000 0.00000000 0.00000000
# 1887         4.88000000      4.40375246 0.00000000 0.00000000 0.00000000
# 1888         4.88000000      4.40375246 0.00000000 0.00000000 0.00000000
# 1889         4.88000000      4.40375246 1.00000000 0.00000000 0.00000000
# 1890         4.88000000      4.40375246 0.00000000 0.00000000 1.00000000
# 1891         4.88000000      4.40375246 0.00000000 0.00000000 0.00000000
# 1892         4.88000000      4.40375246 0.00000000 1.00000000 0.00000000
# 1893         4.88000000      4.40375246 0.00000000 0.00000000 0.00000000
# 1894         4.88000000      4.40375246 0.00000000 0.00000000 0.00000000
# 1895         4.88000000      4.40375246 0.00000000 0.00000000 0.00000000
# 1896         4.88000000      4.40375246 1.00000000 0.00000000 0.00000000
# 1897         4.88000000      4.40375246 0.00000000 0.00000000 1.00000000
# 1898         4.88000000      4.40375246 0.00000000 0.00000000 0.00000000
# 1899         4.88000000      4.40375246 0.00000000 1.00000000 0.00000000
# 1900         4.88000000      4.40375246 0.00000000 0.00000000 0.00000000
# 1901         4.88000000      4.40375246 0.00000000 0.00000000 0.00000000
# 1902         4.88000000      4.40375246 0.00000000 0.00000000 0.00000000
# 1903         4.88000000      4.40375246 1.00000000 0.00000000 0.00000000
# 1904         4.88000000      4.40375246 0.00000000 0.00000000 1.00000000
# 1905         4.88000000      4.40375246 0.00000000 0.00000000 0.00000000
# 1906         4.88000000      4.40375246 0.00000000 1.00000000 0.00000000
# 1907         4.88000000      4.40375246 0.00000000 0.00000000 0.00000000
# 1908         4.88000000      4.40375246 0.00000000 0.00000000 0.00000000
# 1909         4.88000000      4.40375246 0.00000000 0.00000000 0.00000000
# 1910         4.88000000      4.40375246 1.00000000 0.00000000 0.00000000
# 1911         4.88000000      4.40375246 0.00000000 0.00000000 1.00000000
# 1912         4.88000000      4.40375246 0.00000000 0.00000000 0.00000000
#
#          Sunday   Thursday    Tuesday  Wednesday        Jan        Feb  \
# 1885 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1886 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000
# 1887 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000
# 1888 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1889 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1890 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1891 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1892 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1893 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000
# 1894 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000
# 1895 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1896 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1897 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1898 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1899 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1900 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000
# 1901 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000
# 1902 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1903 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1904 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1905 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1906 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1907 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000
# 1908 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000
# 1909 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1910 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1911 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1912 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
#
#             Mar        Apr        May       June       July        Agu  \
# 1885 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1886 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1887 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1888 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1889 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1890 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1891 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1892 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1893 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1894 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1895 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1896 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1897 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1898 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1899 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1900 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1901 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1902 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1903 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1904 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1905 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1906 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1907 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1908 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1909 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1910 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1911 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1912 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000
#
#             Sep        Oct        Nov        Dec      _2011      _2012  \
# 1885 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1886 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1887 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1888 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1889 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1890 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1891 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1892 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1893 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1894 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1895 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1896 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1897 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1898 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1899 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1900 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1901 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1902 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1903 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1904 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1905 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1906 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1907 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1908 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1909 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1910 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1911 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1912 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
#
#           _2013      _2014      _2015      _2016   Cultural   National  \
# 1885 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000
# 1886 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000
# 1887 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000
# 1888 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000
# 1889 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000
# 1890 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000
# 1891 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000
# 1892 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000
# 1893 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000
# 1894 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000
# 1895 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000
# 1896 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000
# 1897 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000
# 1898 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000
# 1899 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000
# 1900 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000
# 1901 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000
# 1902 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000
# 1903 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000
# 1904 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000
# 1905 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000
# 1906 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000
# 1907 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000
# 1908 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000
# 1909 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000
# 1910 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000
# 1911 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000
# 1912 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000
#
#       Religious   Sporting
# 1885 0.00000000 0.00000000
# 1886 0.00000000 0.00000000
# 1887 0.00000000 0.00000000
# 1888 0.00000000 0.00000000
# 1889 0.00000000 0.00000000
# 1890 0.00000000 0.00000000
# 1891 0.00000000 0.00000000
# 1892 0.00000000 0.00000000
# 1893 0.00000000 0.00000000
# 1894 0.00000000 0.00000000
# 1895 0.00000000 0.00000000
# 1896 0.00000000 0.00000000
# 1897 0.00000000 0.00000000
# 1898 0.00000000 0.00000000
# 1899 0.00000000 0.00000000
# 1900 0.00000000 0.00000000
# 1901 0.00000000 0.00000000
# 1902 0.00000000 0.00000000
# 1903 0.00000000 0.00000000
# 1904 0.00000000 0.00000000
# 1905 0.00000000 0.00000000
# 1906 0.00000000 0.00000000
# 1907 0.00000000 0.00000000
# 1908 0.00000000 0.00000000
# 1909 0.00000000 0.00000000
# 1910 0.00000000 0.00000000
# 1911 0.00000000 0.00000000
# 1912 0.00000000 0.00000000

# %% [markdown]
# ### Train & Test

# %%
# train=data[data["date"]<((data["date"].max()-data["date"].min())*0.8)+data["date"].min()]

# %%
# test=data[data["date"]>=((data["date"].max()-data["date"].min())*0.8)+data["date"].min()]
# test.reset_index(drop=True, inplace=True)

# %%
train=data[:-28]

# %%
test=data[-28:]
test.reset_index(drop=True, inplace=True)

# %% [markdown]
# ### Date and Customer Drop

# %%
train=train.drop(["date"], axis=1)
test=test.drop(["date"], axis=1)

# %%
X_train, y_train=train.drop(["Sales"], axis=1), train["Sales"]
X_test, y_test=test.drop(["Sales"], axis=1), test["Sales"]

# %% [markdown]
# # Linear Regression-Elastic Net

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.linear_model import ElasticNet

# %% [markdown]
# ### Grid

# %%
elastic_net_model = ElasticNet()

# %%
param_grid_elastic=[
    {"alpha":[0.1,0.2,0.3,0.4], "l1_ratio":[0.2,0.4,0.6]}
]

# %%
elastic_net = GridSearchCV(estimator=elastic_net_model, param_grid=param_grid_elastic,
                 cv=10,return_train_score=True)

# %%
elastic_net.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=10, estimator=ElasticNet(),
#              param_grid=[{'alpha': [0.1, 0.2, 0.3, 0.4],
#                           'l1_ratio': [0.2, 0.4, 0.6]}],
#              return_train_score=True)

# %%
elastic_predictions=elastic_net.predict(X_test)

# %%
performance_list("Control", elastic_net.predict(X_train), y_train)
# Out:
#       Name  # of inst        Mean  Standard Dev.       FBias        MPE  \
# 0  Control       1885 57.77135279     8.50161119 -0.00000000 0.00729959
#
#         MAPE       RMSE         MAD      WMAPE
# 0 0.17860033 0.31113749 10.27230170 0.17780961

# %%
res_elastic=performance_list("Elastic Net Performance", elastic_predictions, y_test)

# %%
res_elastic
# Out:
#                       Name  # of inst        Mean  Standard Dev.       FBias  \
# 0  Elastic Net Performance         28 63.90269288     6.36103307 -0.13733191
#
#           MPE       MAPE       RMSE         MAD      WMAPE
# 0 -0.13623536 0.19024421 3.28930488 12.29030026 0.19232836

# %% [markdown]
# # Support Vector Machines

# %% [markdown]
# ### Grid

# %%
elastic_net_model = ElasticNet()

# %%
param_grid_elastic=[
    {"alpha":[0.1,0.2,0.3,0.4], "l1_ratio":[0.2,0.4,0.6]}
]

# %%
elastic_net = GridSearchCV(estimator=elastic_net_model, param_grid=param_grid_elastic,
                 cv=10,return_train_score=True)

# %% [markdown]
# ### Linear

# %%
from sklearn.svm import LinearSVR

# %%
sv_regressor=LinearSVR()

# %% [markdown]
# ### Grid

# %%
param_grid_svm_linear=[
    {"epsilon":[0.5,1,1.5]}
]

# %%
sv_regressor = GridSearchCV(estimator=sv_regressor, param_grid=param_grid_svm_linear,
                 cv=10,return_train_score=True)

# %%
sv_regressor.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=10, estimator=LinearSVR(),
#              param_grid=[{'epsilon': [0.5, 1, 1.5]}], return_train_score=True)

# %% [markdown]
# ### Poly with Kernel

# %%
from sklearn.svm import SVR

# %% [markdown]
# ### Grid

# %%
param_grid_svm_poly=[
    {"degree":[2,3], "epsilon":[0.02,0.05, 0.1, 0.15, 0.2]}
]

# %%
sv_regressor_poly=SVR(kernel="poly")

# %%
sv_regressor_poly = GridSearchCV(estimator=sv_regressor_poly, param_grid=param_grid_svm_poly,
                 cv=10,return_train_score=True)

# %%
sv_regressor_poly.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=10, estimator=SVR(kernel='poly'),
#              param_grid=[{'degree': [2, 3],
#                           'epsilon': [0.02, 0.05, 0.1, 0.15, 0.2]}],
#              return_train_score=True)

# %%
sv_regressor_poly.best_estimator_
# Out:
# SVR(epsilon=0.02, kernel='poly')

# %% [markdown]
# ### Predictions

# %%
svm_predictions_linear=sv_regressor.predict(X_test)

# %%
res_svr_linear=performance_list("Support Vector Regressor Linear Performance", svm_predictions_linear, y_test)

# %%
svm_predictions_poly=sv_regressor_poly.predict(X_test)

# %%
res_svr_poly=performance_list("Support Vector Regressor Polynomial Performance", svm_predictions_poly, y_test)

# %%
performance_list("Control", sv_regressor.predict(X_train), y_train)
# Out:
#       Name  # of inst        Mean  Standard Dev.       FBias         MPE  \
# 0  Control       1885 56.65005935    10.67111889 -0.01979333 -0.01779452
#
#         MAPE       RMSE        MAD      WMAPE
# 0 0.17530151 0.30348496 9.83426387 0.17359671

# %%
performance_list("Control", sv_regressor_poly.predict(X_train), y_train)
# Out:
#       Name  # of inst        Mean  Standard Dev.       FBias         MPE  \
# 0  Control       1885 55.94978872     5.19606874 -0.03255712 -0.02292071
#
#         MAPE       RMSE         MAD      WMAPE
# 0 0.19710258 0.33999831 11.08974635 0.19820890

# %% [markdown]
# ### Results

# %%
res_svr_linear
# Out:
#                                           Name  # of inst        Mean  \
# 0  Support Vector Regressor Linear Performance         28 69.15134377
#
#    Standard Dev.       FBias         MPE       MAPE       RMSE         MAD  \
# 0     8.19897270 -0.05100736 -0.05231706 0.15541354 2.92604910 10.94322399
#
#        WMAPE
# 0 0.15825034

# %%
res_svr_poly
# Out:
#                                               Name  # of inst        Mean  \
# 0  Support Vector Regressor Polynomial Performance         28 58.52721636
#
#    Standard Dev.       FBias         MPE       MAPE       RMSE         MAD  \
# 0     3.62099831 -0.24179102 -0.23825162 0.26559908 3.96592264 15.72427439
#
#        WMAPE
# 0 0.26866602

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# ### Grid

# %%
param_grid=[
    {"n_estimators":[200,300,500], "max_features":[8,12,16],
     "bootstrap":[False,True]}
]

# %%
random_reg=RandomForestRegressor()
grid_search = GridSearchCV(estimator=random_reg, param_grid=param_grid,
                 cv=10,return_train_score=True)

# %% [markdown]
# ### Predictions

# %%
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=10, estimator=RandomForestRegressor(),
#              param_grid=[{'bootstrap': [False, True],
#                           'max_features': [8, 12, 16],
#                           'n_estimators': [200, 300, 500]}],
#              return_train_score=True)

# %%
grid_search.best_params_
# Out:
# {'bootstrap': True, 'max_features': 8, 'n_estimators': 500}

# %% [markdown]
# ### Results

# %%
rf_predictions=grid_search.predict(X_test)

# %%
res_rf=performance_list("Random Forest Performance", rf_predictions, y_test)

# %%
res_rf
# Out:
#                         Name  # of inst        Mean  Standard Dev.  \
# 0  Random Forest Performance         28 66.39175476    11.83363188
#
#         FBias         MPE       MAPE       RMSE         MAD      WMAPE
# 0 -0.09469273 -0.11289906 0.20449166 3.52853850 13.37013061 0.20138240

# %%
performance_list("Control", grid_search.predict(X_train), y_train)
# Out:
#       Name  # of inst        Mean  Standard Dev.      FBias        MPE  \
# 0  Control       1885 57.81668028    14.31985435 0.00078399 0.01080191
#
#         MAPE       RMSE        MAD      WMAPE
# 0 0.08139754 0.14227788 4.57336282 0.07910110

# %% [markdown]
# # Feature Extraction

# %%
from sklearn.tree import DecisionTreeRegressor

# %% [markdown]
# ### Train Node Selection

# %%
estimator = DecisionTreeRegressor(min_samples_leaf=10, max_depth=5)
estimator.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=5, min_samples_leaf=10)

# %%
on_leaf = estimator.apply(X_train)

# %%
X_train_ext=X_train[:]

# %%
X_train_ext["Node"] = on_leaf.tolist()
# Out:
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
X_train_ext
# Out:
#       snap_CA  snap_TX  snap_WI  sell_price_mean  sell_price_median  \
# 0           0        0        0       5.95971429         5.05000000
# 1           0        0        0       5.95971429         5.05000000
# 2           0        0        0       5.95971429         5.05000000
# 3           1        1        0       5.95971429         5.05000000
# 4           1        0        1       5.95971429         5.05000000
# ...       ...      ...      ...              ...                ...
# 1880        0        0        0       6.01875969         4.88000000
# 1881        0        0        0       6.01875969         4.88000000
# 1882        0        0        0       6.01875969         4.88000000
# 1883        0        0        0       6.01899225         4.88000000
# 1884        0        0        0       6.01899225         4.88000000
#
#       sell_price_std     Friday     Monday   Saturday     Sunday   Thursday  \
# 0         4.09462637 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000
# 1         4.09462637 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000
# 2         4.09462637 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000
# 3         4.09462637 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 4         4.09462637 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# ...              ...        ...        ...        ...        ...        ...
# 1880      4.40403739 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1881      4.40403739 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000
# 1882      4.40403739 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1883      4.40375246 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000
# 1884      4.40375246 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000
#
#         Tuesday  Wednesday        Jan        Feb        Mar        Apr  \
# 0    0.00000000 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000
# 1    0.00000000 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000
# 2    0.00000000 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000
# 3    1.00000000 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000
# 4    0.00000000 1.00000000 0.00000000 1.00000000 0.00000000 0.00000000
# ...         ...        ...        ...        ...        ...        ...
# 1880 0.00000000 1.00000000 0.00000000 0.00000000 1.00000000 0.00000000
# 1881 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000
# 1882 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000
# 1883 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000
# 1884 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000
#
#             May       June       July        Agu        Sep        Oct  \
# 0    0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1    0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 2    0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 3    0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 4    0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# ...         ...        ...        ...        ...        ...        ...
# 1880 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1881 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1882 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1883 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1884 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
#
#             Nov        Dec      _2011      _2012      _2013      _2014  \
# 0    0.00000000 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000
# 1    0.00000000 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000
# 2    0.00000000 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000
# 3    0.00000000 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000
# 4    0.00000000 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000
# ...         ...        ...        ...        ...        ...        ...
# 1880 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1881 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1882 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1883 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1884 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
#
#           _2015      _2016   Cultural   National  Religious   Sporting  Node
# 0    0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000    23
# 1    0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000    40
# 2    0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000     9
# 3    0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000     9
# 4    0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000     9
# ...         ...        ...        ...        ...        ...        ...   ...
# 1880 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000    12
# 1881 0.00000000 1.00000000 0.00000000 0.00000000 1.00000000 0.00000000    12
# 1882 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000    12
# 1883 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000    27
# 1884 0.00000000 1.00000000 1.00000000 0.00000000 0.00000000 0.00000000    44
#
# [1885 rows x 36 columns]

# %% [markdown]
# ### Test Node Selection

# %%
on_leaf_test = estimator.apply(X_test)

# %%
X_test_ext=X_test[:]

# %%
X_test_ext["Node"] = on_leaf_test.tolist()
# Out:
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
X_test_ext
# Out:
#     snap_CA  snap_TX  snap_WI  sell_price_mean  sell_price_median  \
# 0         0        0        0       6.01899225         4.88000000
# 1         0        0        0       6.01899225         4.88000000
# 2         0        0        0       6.01899225         4.88000000
# 3         0        0        0       6.01899225         4.88000000
# 4         1        1        0       6.01899225         4.88000000
# 5         1        0        1       6.01899225         4.88000000
# 6         1        1        1       6.01899225         4.88000000
# 7         1        0        0       6.01899225         4.88000000
# 8         1        1        1       6.01899225         4.88000000
# 9         1        1        1       6.01899225         4.88000000
# 10        1        1        0       6.01899225         4.88000000
# 11        1        0        1       6.01899225         4.88000000
# 12        1        1        1       6.01899225         4.88000000
# 13        1        0        0       6.01899225         4.88000000
# 14        0        1        1       6.01899225         4.88000000
# 15        0        1        1       6.01899225         4.88000000
# 16        0        1        0       6.01899225         4.88000000
# 17        0        0        1       6.01899225         4.88000000
# 18        0        1        1       6.01899225         4.88000000
# 19        0        0        0       6.01899225         4.88000000
# 20        0        0        0       6.01899225         4.88000000
# 21        0        0        0       6.01899225         4.88000000
# 22        0        0        0       6.01899225         4.88000000
# 23        0        0        0       6.01899225         4.88000000
# 24        0        0        0       6.01899225         4.88000000
# 25        0        0        0       6.01899225         4.88000000
# 26        0        0        0       6.01899225         4.88000000
# 27        0        0        0       6.01899225         4.88000000
#
#     sell_price_std     Friday     Monday   Saturday     Sunday   Thursday  \
# 0       4.40375246 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000
# 1       4.40375246 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 2       4.40375246 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 3       4.40375246 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000
# 4       4.40375246 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 5       4.40375246 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000
# 6       4.40375246 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000
# 7       4.40375246 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000
# 8       4.40375246 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 9       4.40375246 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 10      4.40375246 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000
# 11      4.40375246 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 12      4.40375246 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000
# 13      4.40375246 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000
# 14      4.40375246 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000
# 15      4.40375246 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 16      4.40375246 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 17      4.40375246 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000
# 18      4.40375246 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 19      4.40375246 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000
# 20      4.40375246 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000
# 21      4.40375246 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000
# 22      4.40375246 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 23      4.40375246 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 24      4.40375246 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000
# 25      4.40375246 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 26      4.40375246 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000
# 27      4.40375246 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000
#
#       Tuesday  Wednesday        Jan        Feb        Mar        Apr  \
# 0  0.00000000 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000
# 1  1.00000000 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000
# 2  0.00000000 1.00000000 0.00000000 0.00000000 1.00000000 0.00000000
# 3  0.00000000 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000
# 4  0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000
# 5  0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000
# 6  0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000
# 7  0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000
# 8  1.00000000 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000
# 9  0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 1.00000000
# 10 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000
# 11 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000
# 12 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000
# 13 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000
# 14 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000
# 15 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000
# 16 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 1.00000000
# 17 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000
# 18 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000
# 19 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000
# 20 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000
# 21 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000
# 22 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000
# 23 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 1.00000000
# 24 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000
# 25 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000
# 26 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000
# 27 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000
#
#           May       June       July        Agu        Sep        Oct  \
# 0  0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1  0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 2  0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 3  0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 4  0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 5  0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 6  0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 7  0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 8  0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 9  0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 10 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 11 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 12 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 13 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 14 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 15 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 16 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 17 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 18 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 19 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 20 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 21 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 22 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 23 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 24 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 25 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 26 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 27 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
#
#           Nov        Dec      _2011      _2012      _2013      _2014  \
# 0  0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 1  0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 2  0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 3  0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 4  0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 5  0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 6  0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 7  0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 8  0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 9  0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 10 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 11 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 12 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 13 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 14 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 15 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 16 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 17 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 18 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 19 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 20 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 21 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 22 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 23 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 24 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 25 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 26 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 27 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
#
#         _2015      _2016   Cultural   National  Religious   Sporting  Node
# 0  0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000    12
# 1  0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000    12
# 2  0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000    12
# 3  0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000    12
# 4  0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000    12
# 5  0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000    27
# 6  0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000    44
# 7  0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000    12
# 8  0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000    12
# 9  0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000    12
# 10 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000    12
# 11 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000    12
# 12 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000    28
# 13 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000    44
# 14 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000    12
# 15 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000    12
# 16 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000    12
# 17 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000    12
# 18 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000    12
# 19 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000    27
# 20 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000    44
# 21 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000    12
# 22 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000    12
# 23 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000    12
# 24 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000    12
# 25 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000    12
# 26 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000    27
# 27 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000    44

# %% [markdown]
# ### Feature Adding

# %% [markdown]
# Ma=1 kullanıldı daha hızlı bir şekilde anlaşılması için

# %%
Xframes_feature=[X_train_ext, X_test_ext]
yframes_feature=[y_train, y_test]
X_concat=pd.concat(Xframes_feature)
Y_concat=pd.concat(yframes_feature)
final_frame=[X_concat, Y_concat]
concated_df=pd.concat(final_frame, axis=1)

# %%
concated_df["new_feature"] = concated_df.groupby(["Node"])["Sales"].shift(+1)

# %%
X_test_new=concated_df.iloc[len(X_train):].drop(["Sales","Node"], axis=1)

y_test_new=concated_df.iloc[len(X_train):]["Sales"]

# %%
train_new=concated_df.iloc[:len(X_train)]

# %%
train_new.dropna(inplace=True);
train_new.reset_index(drop=True, inplace=True)
# Out:
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
X_train_new=train_new.drop(["Sales","Node"], axis=1)

y_train_new=train_new["Sales"]

# %% [markdown]
# ## Short Prediction Quality

# %% [markdown]
# # Linear Regression-Elastic Net

# %% [markdown]
# ### Grid

# %%
elastic_net_model_new = ElasticNet()

# %%
param_grid_elastic=[
    {"alpha":[0.1,0.2,0.3,0.4], "l1_ratio":[0.2,0.4,0.6]}
]

# %%
elastic_net_new = GridSearchCV(estimator=elastic_net_model_new, param_grid=param_grid_elastic,
                 cv=10,return_train_score=True)

# %%
elastic_net_new.fit(X_train_new, y_train_new)
# Out:
# GridSearchCV(cv=10, estimator=ElasticNet(),
#              param_grid=[{'alpha': [0.1, 0.2, 0.3, 0.4],
#                           'l1_ratio': [0.2, 0.4, 0.6]}],
#              return_train_score=True)

# %%
elastic_predictions_new=elastic_net_new.predict(X_test_new)

# %%
res_elastic_new=performance_list("Elastic Net Performance with Feature Extraction", elastic_predictions_new, y_test_new)

# %%
res_elastic_new
# Out:
#                                               Name  # of inst        Mean  \
# 0  Elastic Net Performance with Feature Extraction         28 65.45840976
#
#    Standard Dev.       FBias         MPE       MAPE       RMSE         MAD  \
# 0     7.42898339 -0.11030151 -0.11352541 0.18797542 3.29598548 12.35466176
#
#        WMAPE
# 0 0.18874063

# %% [markdown]
# ### SVM

# %% [markdown]
# #### Linear

# %%
sv_regressor_new=LinearSVR()

# %% [markdown]
# ### Grid

# %%
param_grid_svm_linear=[
    {"epsilon":[0.5,1,1.5]}
]

# %%
sv_regressor_new = GridSearchCV(estimator=sv_regressor_new, param_grid=param_grid_svm_linear,
                 cv=10,return_train_score=True,)

# %%
sv_regressor_new.fit(X_train_new, y_train_new,max_iter=10000)
# Out:
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
# TypeError: fit() got an unexpected keyword argument 'max_iter'
#
#   FitFailedWarning)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-294-f49d2f3b47dd> in <module>
# ----> 1 sv_regressor_new.fit(X_train_new, y_train_new,max_iter=10000)
#
# ~\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     763             refit_start_time = time.time()
#     764             if y is not None:
# --> 765                 self.best_estimator_.fit(X, y, **fit_params)
#     766             else:
#     767                 self.best_estimator_.fit(X, **fit_params)
#
# TypeError: fit() got an unexpected keyword argument 'max_iter'

# %%
svm_predictions_new=sv_regressor_new.predict(X_test_new)

res_svr_new=performance_list("SVR Linear Performance with Feature Extraction", 
                                svm_predictions_new, y_test_new)

res_svr_new
# Out:
#                                              Name  # of inst        Mean  \
# 0  SVR Linear Performance with Feature Extraction         28 70.12257947
#
#    Standard Dev.       FBias         MPE       MAPE       RMSE         MAD  \
# 0     8.30984827 -0.03645034 -0.03898268 0.15832474 2.97371873 11.25921743
#
#        WMAPE
# 0 0.16056479

# %% [markdown]
# ## Poly

# %% [markdown]
# ### Grid

# %%
param_grid_svm_poly=[
    {"degree":[2,3,4], "epsilon":[0.02,0.05, 0.1, 0.15, 0.2]}
]

# %%
sv_regressor_poly_new=SVR(kernel="poly")

# %%
sv_regressor_poly_new = GridSearchCV(estimator=sv_regressor_poly_new, param_grid=param_grid_svm_poly,
                 cv=10,return_train_score=True)

# %%
sv_regressor_poly_new.fit(X_train_new, y_train_new)
# Out:
# GridSearchCV(cv=10, estimator=SVR(kernel='poly'),
#              param_grid=[{'degree': [2, 3, 4],
#                           'epsilon': [0.02, 0.05, 0.1, 0.15, 0.2]}],
#              return_train_score=True)

# %%
sv_regressor_poly_new.best_estimator_
# Out:
# SVR(degree=2, epsilon=0.15, kernel='poly')

# %%
svm_predictions_poly_new=sv_regressor_poly_new.predict(X_test_new)

res_svr_poly_new=performance_list("SVR Polynomail Performance with Feature Extraction", 
                                svm_predictions_poly_new, y_test_new)

res_svr_poly_new
# Out:
#                                                 Name  # of inst        Mean  \
# 0  SVR Polynomail Performance with Feature Extrac...         28 63.11630594
#
#    Standard Dev.       FBias         MPE       MAPE       RMSE         MAD  \
# 0     9.89227854 -0.15150230 -0.16967750 0.24347019 3.97578279 15.12270154
#
#        WMAPE
# 0 0.23960055

# %% [markdown]
# ### Random Forest

# %%
random_reg_new=RandomForestRegressor()
grid_search_new = GridSearchCV(estimator=random_reg_new, param_grid=param_grid,
                 cv=10,return_train_score=True)

# %%
grid_search_new.fit(X_train_new, y_train_new)

grid_search_new.best_params_
# Out:
# {'bootstrap': True, 'max_features': 8, 'n_estimators': 300}

# %%
rf_predictions_new=grid_search_new.predict(X_test_new)

res_rf_new=performance_list("Random Forest Performance with Feature Extraction", rf_predictions_new, y_test_new)

res_rf_new
# Out:
#                                                 Name  # of inst        Mean  \
# 0  Random Forest Performance with Feature Extraction         28 66.45612500
#
#    Standard Dev.       FBias         MPE       MAPE       RMSE         MAD  \
# 0     9.76839206 -0.09363240 -0.10262486 0.19017395 3.26751868 12.56742659
#
#        WMAPE
# 0 0.18910863

# %% [markdown]
# # General Result Table

# %%
pd.options.display.float_format = '{:,.8f}'.format

# %%
result_frames=[res_elastic,res_svr_linear,res_svr_poly,res_rf, res_elastic_new,res_svr_new,res_svr_poly_new,res_rf_new]
total_result=pd.concat(result_frames)
total_result.reset_index(drop=True, inplace=True)

# %%
total_result
# Out:
#                                                 Name  # of inst        Mean  \
# 0                            Elastic Net Performance         28 63.90269288
# 1        Support Vector Regressor Linear Performance         28 69.15134377
# 2    Support Vector Regressor Polynomial Performance         28 58.52721636
# 3                          Random Forest Performance         28 66.39175476
# 4    Elastic Net Performance with Feature Extraction         28 65.45840976
# 5     SVR Linear Performance with Feature Extraction         28 70.12257947
# 6  SVR Polynomail Performance with Feature Extrac...         28 63.11630594
# 7  Random Forest Performance with Feature Extraction         28 66.45612500
#
#    Standard Dev.       FBias         MPE       MAPE       RMSE         MAD  \
# 0     6.36103307 -0.13733191 -0.13623536 0.19024421 3.28930488 12.29030026
# 1     8.19897270 -0.05100736 -0.05231706 0.15541354 2.92604910 10.94322399
# 2     3.62099831 -0.24179102 -0.23825162 0.26559908 3.96592264 15.72427439
# 3    11.83363188 -0.09469273 -0.11289906 0.20449166 3.52853850 13.37013061
# 4     7.42898339 -0.11030151 -0.11352541 0.18797542 3.29598548 12.35466176
# 5     8.30984827 -0.03645034 -0.03898268 0.15832474 2.97371873 11.25921743
# 6     9.89227854 -0.15150230 -0.16967750 0.24347019 3.97578279 15.12270154
# 7     9.76839206 -0.09363240 -0.10262486 0.19017395 3.26751868 12.56742659
#
#        WMAPE
# 0 0.19232836
# 1 0.15825034
# 2 0.26866602
# 3 0.20138240
# 4 0.18874063
# 5 0.16056479
# 6 0.23960055
# 7 0.18910863

# %% [markdown]
# ## RFOverfitting

# %%
rf_control=grid_search.predict(X_train)

performance_list("RF Performance without Feature Extraction",rf_control, y_train)
# Out:
#                                         Name  # of inst        Mean  \
# 0  RF Performance without Feature Extraction       1885 57.81668028
#
#    Standard Dev.      FBias        MPE       MAPE       RMSE        MAD  \
# 0    14.31985435 0.00078399 0.01080191 0.08139754 0.14227788 4.57336282
#
#        WMAPE
# 0 0.07910110

# %%
rf_control=grid_search.predict(X_test)

performance_list("RF Performance without Feature Extraction",rf_control, y_test)
# Out:
#                                         Name  # of inst        Mean  \
# 0  RF Performance without Feature Extraction         28 66.39175476
#
#    Standard Dev.       FBias         MPE       MAPE       RMSE         MAD  \
# 0    11.83363188 -0.09469273 -0.11289906 0.20449166 3.52853850 13.37013061
#
#        WMAPE
# 0 0.20138240

# %%
rf_control_feature=grid_search_new.predict(X_train_new)

performance_list("RF Performance with Feature Extraction", rf_control_feature, y_train_new)
# Out:
#                                      Name  # of inst        Mean  \
# 0  RF Performance with Feature Extraction       1858 57.77586154
#
#    Standard Dev.      FBias        MPE       MAPE       RMSE        MAD  \
# 0    14.20566664 0.00154219 0.01384074 0.06943960 0.11757326 3.86022421
#
#        WMAPE
# 0 0.06681379

# %%
rf_control_feature=grid_search_new.predict(X_test_new)

performance_list("RF Performance with Feature Extraction", rf_control_feature, y_test_new)
# Out:
#                                      Name  # of inst        Mean  \
# 0  RF Performance with Feature Extraction         28 66.45612500
#
#    Standard Dev.       FBias         MPE       MAPE       RMSE         MAD  \
# 0     9.76839206 -0.09363240 -0.10262486 0.19017395 3.26751868 12.56742659
#
#        WMAPE
# 0 0.18910863

# %% [markdown]
# # Feature Control

# %%
plt.plot(data.Sales[:28])

# %%
from statsmodels.graphics.tsaplots import plot_acf

# %%
plot_acf(data.Sales, lags=28)
plt.show()

# %% [markdown]
# ## Node Control

# %%
concated_df.Node.value_counts()
# Out:
# 15    516
# 12    280
# 8     185
# 9     130
# 16    129
# 30     74
# 48     72
# 49     60
# 13     60
# 31     55
# 27     48
# 5      45
# 23     29
# 51     25
# 38     22
# 20     22
# 28     21
# 6      20
# 52     18
# 34     17
# 24     15
# 41     14
# 44     14
# 37     11
# 40     11
# 21     10
# 45     10
# Name: Node, dtype: int64

# %%
concated_df[concated_df["Node"]==6].head()
# Out:
#      snap_CA  snap_TX  snap_WI  sell_price_mean  sell_price_median  \
# 464        1        1        0       5.80757576         4.97000000
# 465        1        0        1       5.80757576         4.97000000
# 466        1        1        1       5.80757576         4.97000000
# 467        1        0        0       5.80757576         4.97000000
# 468        0        1        1       5.80757576         4.97000000
#
#      sell_price_std     Friday     Monday   Saturday     Sunday   Thursday  \
# 464      3.98970156 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000
# 465      3.98970156 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 466      3.98970156 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 467      3.98970156 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000
# 468      3.98970156 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000
#
#        Tuesday  Wednesday        Jan        Feb        Mar        Apr  \
# 464 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 465 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 466 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 467 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 468 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
#
#            May       June       July        Agu        Sep        Oct  \
# 464 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 465 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 466 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 467 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 468 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
#
#            Nov        Dec      _2011      _2012      _2013      _2014  \
# 464 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000
# 465 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000
# 466 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000
# 467 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000
# 468 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000
#
#          _2015      _2016   Cultural   National  Religious   Sporting  Node  \
# 464 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000     6
# 465 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000     6
# 466 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000     6
# 467 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000     6
# 468 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000     6
#
#      Sales  new_feature
# 464     67          nan
# 465     51  67.00000000
# 466     34  51.00000000
# 467     64  34.00000000
# 468     48  64.00000000

# %%
concated_df[concated_df["Node"]==9].head()
# Out:
#    snap_CA  snap_TX  snap_WI  sell_price_mean  sell_price_median  \
# 2        0        0        0       5.95971429         5.05000000
# 3        1        1        0       5.95971429         5.05000000
# 4        1        0        1       5.95971429         5.05000000
# 5        1        1        1       5.95971429         5.05000000
# 6        1        0        0       5.95971429         5.05000000
#
#    sell_price_std     Friday     Monday   Saturday     Sunday   Thursday  \
# 2      4.09462637 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000
# 3      4.09462637 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 4      4.09462637 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 5      4.09462637 0.00000000 0.00000000 0.00000000 0.00000000 1.00000000
# 6      4.09462637 1.00000000 0.00000000 0.00000000 0.00000000 0.00000000
#
#      Tuesday  Wednesday        Jan        Feb        Mar        Apr  \
# 2 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000
# 3 1.00000000 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000
# 4 0.00000000 1.00000000 0.00000000 1.00000000 0.00000000 0.00000000
# 5 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000
# 6 0.00000000 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000
#
#          May       June       July        Agu        Sep        Oct  \
# 2 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 3 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 4 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 5 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
# 6 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000
#
#          Nov        Dec      _2011      _2012      _2013      _2014  \
# 2 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000
# 3 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000
# 4 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000
# 5 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000
# 6 0.00000000 0.00000000 1.00000000 0.00000000 0.00000000 0.00000000
#
#        _2015      _2016   Cultural   National  Religious   Sporting  Node  \
# 2 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000     9
# 3 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000     9
# 4 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000     9
# 5 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000     9
# 6 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000 0.00000000     9
#
#    Sales  new_feature
# 2     41          nan
# 3     46  41.00000000
# 4     28  46.00000000
# 5     57  28.00000000
# 6     25  57.00000000

# %%
concated_df[concated_df["Node"]==42].head()
# Out:
# Empty DataFrame
# Columns: [snap_CA, snap_TX, snap_WI, sell_price_mean, sell_price_median, sell_price_std, Friday, Monday, Saturday, Sunday, Thursday, Tuesday, Wednesday, Jan, Feb, Mar, Apr, May, June, July, Agu, Sep, Oct, Nov, Dec, _2011, _2012, _2013, _2014, _2015, _2016, Cultural, National, Religious, Sporting, Node, Sales, new_feature]
# Index: []

# %% [markdown]
# # General Function

# %%
def result_obtain(df, feature_set, name, lag):

    df[name]=feature_set
    
    #     train=df[df["date"]<((df["date"].max()-df["date"].min())*0.8)+df["date"].min()]
    #     test=df[df["date"]>=((df["date"].max()-df["date"].min())*0.8)+df["date"].min()]
    train=df[:-28]

    test=df[-28:]
    test.reset_index(drop=True, inplace=True)

    ### Date and Customer Drop

    train=train.drop(["date"], axis=1)
    test=test.drop(["date"], axis=1)

    X_train, y_train=train.drop(["Sales"], axis=1), train["Sales"]
    X_test, y_test=test.drop(["Sales"], axis=1), test["Sales"]
    
    train.dropna(inplace=True);
    train.reset_index(drop=True, inplace=True)
    train.index += lag

    X_train, y_train=train.drop(["Sales"], axis=1), train["Sales"]
    X_test, y_test=test.drop(["Sales"], axis=1), test["Sales"]
    
    
    
    # Linear Regression-Elastic Net

    elastic_net_function = ElasticNet()

    param_grid_elastic=[
        {"alpha":[0.1,0.2,0.3,0.4], "l1_ratio":[0.2,0.4,0.6]}
    ]

    elastic_net_function = GridSearchCV(estimator=elastic_net_function, param_grid=param_grid_elastic,
                     cv=10,return_train_score=True)
    
    elastic_net_function.fit(X_train, y_train)
    

    elastic_predictions=elastic_net_function.predict(X_test)

    res_elastic=performance_list(["Elastic Net Performance Lag " + str(lag)], elastic_predictions, y_test)

    
    
    # Support Vector Machines

    ### Linear

    sv_regressor=LinearSVR()
    

    ### Grid

    param_grid_svm_linear=[
        {"epsilon":[0.5,1,1.5]}
    ]

    sv_regressor_function = GridSearchCV(estimator=sv_regressor, param_grid=param_grid_svm_linear,
                     cv=10,return_train_score=True)

    sv_regressor_function.fit(X_train, y_train)


    
    sv_regressor_poly=SVR(kernel="poly")
        
    ### Grid

    param_grid_svm_poly=[
        {"degree":[2,3], "epsilon":[0.02,0.05, 0.1, 0.15, 0.2]}
    ]


    sv_regressor_poly_function = GridSearchCV(estimator=sv_regressor_poly, param_grid=param_grid_svm_poly,
                     cv=10,return_train_score=True)

    sv_regressor_poly_function.fit(X_train, y_train)


    ### Predictions

    svm_predictions_linear=sv_regressor_function.predict(X_test)
    
    svm_predictions_poly=sv_regressor_poly_function.predict(X_test)


    ### Results    

    res_svr_poly=performance_list(["SVR Polynomial Performance Lag " + str(lag)], svm_predictions_poly, y_test)

    res_svr_linear=performance_list(["SVR Linear Performance Lag " + str(lag)], svm_predictions_linear, y_test)

    
    
    
    # Random Forest
    
    ### Grid

    param_grid=[
        {"n_estimators":[200,300,500], "max_features":[8,12,16],
         "bootstrap":[False,True]}
    ]

    random_reg_function=RandomForestRegressor()
    grid_search = GridSearchCV(estimator=random_reg_function, param_grid=param_grid,
                     cv=10,return_train_score=True)

    ### Predictions

    grid_search.fit(X_train, y_train)

    ### Results

    rf_predictions=grid_search.predict(X_test)

    res_rf=performance_list(["Random Forest Performance Lag " + str(lag)], rf_predictions, y_test)
    
    res_df=[res_elastic, res_svr_linear, res_svr_poly, res_rf]

    total_res=pd.concat(res_df)
    
    return total_res

# %%
res1=result_obtain(data.copy(), data["Sales"].shift(+1), "lag1", 1)
# Out:
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\bahad\anaconda3\envs\r-tutorial\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %%
res1
# Out:
#                                Name  # of inst        Mean  Standard Dev.  \
# 0     Elastic Net Performance Lag 1         28 64.88007597     7.22862603
# 0      SVR Linear Performance Lag 1         28 72.39899445     8.83969541
# 0  SVR Polynomial Performance Lag 1         28 59.79060710     5.98613441
# 0   Random Forest Performance Lag 1         28 66.21010119    11.57352912
#
#         FBias         MPE       MAPE       RMSE         MAD      WMAPE
# 0 -0.12019862 -0.12104072 0.18187176 3.24047951 11.96728489 0.18445239
# 0 -0.00386161 -0.00590963 0.14480593 2.89167360 10.70421260 0.14785029
# 0 -0.21555166 -0.22265872 0.27168420 4.09628569 16.24523727 0.27170216
# 0 -0.09769612 -0.11286757 0.19885076 3.42757658 13.06075595 0.19726229

# %%
total_result
# Out:
#                                                 Name  # of inst        Mean  \
# 0                            Elastic Net Performance         28 63.90269288
# 1        Support Vector Regressor Linear Performance         28 69.15134377
# 2    Support Vector Regressor Polynomial Performance         28 58.52721636
# 3                          Random Forest Performance         28 66.39175476
# 4    Elastic Net Performance with Feature Extraction         28 65.45840976
# 5     SVR Linear Performance with Feature Extraction         28 70.12257947
# 6  SVR Polynomail Performance with Feature Extrac...         28 63.11630594
# 7  Random Forest Performance with Feature Extraction         28 66.45612500
#
#    Standard Dev.       FBias         MPE       MAPE       RMSE         MAD  \
# 0     6.36103307 -0.13733191 -0.13623536 0.19024421 3.28930488 12.29030026
# 1     8.19897270 -0.05100736 -0.05231706 0.15541354 2.92604910 10.94322399
# 2     3.62099831 -0.24179102 -0.23825162 0.26559908 3.96592264 15.72427439
# 3    11.83363188 -0.09469273 -0.11289906 0.20449166 3.52853850 13.37013061
# 4     7.42898339 -0.11030151 -0.11352541 0.18797542 3.29598548 12.35466176
# 5     8.30984827 -0.03645034 -0.03898268 0.15832474 2.97371873 11.25921743
# 6     9.89227854 -0.15150230 -0.16967750 0.24347019 3.97578279 15.12270154
# 7     9.76839206 -0.09363240 -0.10262486 0.19017395 3.26751868 12.56742659
#
#        WMAPE
# 0 0.19232836
# 1 0.15825034
# 2 0.26866602
# 3 0.20138240
# 4 0.18874063
# 5 0.16056479
# 6 0.23960055
# 7 0.18910863
